# %%
import pandas as pd
import numpy as np
import sys

# %%
np.set_printoptions(threshold=sys.maxsize)

# %%
df = pd.read_csv('Parking_Violations_Issued_-_Fiscal_Year_2017.csv')
# Out:
# /Users/urvakshirani/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (18,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#    Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0      5092469481  GZH7067                 NY        PAS  07/10/2016
# 1      5092451658  GZH7067                 NY        PAS  07/08/2016
# 2      4006265037  FZX9232                 NY        PAS  08/23/2016
# 3      8478629828  66623ME                 NY        COM  06/14/2017
# 4      7868300310  37033JV                 NY        COM  11/21/2016
#
#    Violation Code Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  \
# 0               7              SUBN        TOYOT              V             0
# 1               7              SUBN        TOYOT              V             0
# 2               5              SUBN         FORD              V             0
# 3              47              REFG        MITSU              T         10610
# 4              69              DELV        INTER              T         10510
#
#    ...  Vehicle Color  Unregistered Vehicle?  Vehicle Year  Meter Number  \
# ...

# %%
df = df[['Registration State', 'Plate Type','Violation Code','Vehicle Body Type', 'Vehicle Make','Violation Location','Violation County','Street Name','Vehicle Color','Vehicle Year']]

# %%
df.columns
# Out:
# Index(['Registration State', 'Plate Type', 'Violation Code',
#        'Vehicle Body Type', 'Vehicle Make', 'Violation Location',
#        'Violation County', 'Street Name', 'Vehicle Color', 'Vehicle Year'],
#       dtype='object')

# %%
df.head()
# Out:
#   Registration State Plate Type  Violation Code Vehicle Body Type  \
# 0                 NY        PAS               7              SUBN
# 1                 NY        PAS               7              SUBN
# 2                 NY        PAS               5              SUBN
# 3                 NY        COM              47              REFG
# 4                 NY        COM              69              DELV
#
#   Vehicle Make  Violation Location Violation County           Street Name  \
# 0        TOYOT                 NaN               BX  ALLERTON AVE (W/B) @
# 1        TOYOT                 NaN               BX  ALLERTON AVE (W/B) @
# 2         FORD                 NaN               BX  SB WEBSTER AVE @ E 1
# 3        MITSU                14.0               NY               7th Ave
# 4        INTER                13.0               NY               6th Ave
#
#   Vehicle Color  Vehicle Year
# 0            GY          2001
# 1            GY          2001
# ...

# %%
df.dropna(inplace=True)

# %%
df = df.sample(n=800000,replace=False)

# %%
df["Violation County"].unique()
# Out:
# array(['BX', 'K', 'Q', 'NY', 'R'], dtype=object)

# %%
df.loc[df["Violation County"] == "Q", "Violation County"] = 'QNS'
df.loc[df["Violation County"] == "BRONX", "Violation County"] = 'BX'

# %%
df.loc[df["Vehicle Color"] == "GY", "Vehicle Color"] = 'GREY'
df.loc[df["Vehicle Color"] == "WH", "Vehicle Color"] = 'WHITE'
df.loc[df["Vehicle Color"] == "BK", "Vehicle Color"] = 'BLACK'
df.loc[df["Vehicle Color"] == "BL", "Vehicle Color"] = 'BLUE'
df.loc[df["Vehicle Color"] == "RD", "Vehicle Color"] = 'RED'
df.loc[df["Vehicle Color"] == "GR", "Vehicle Color"] = 'GREEN'
df.loc[df["Vehicle Color"] == "BLK", "Vehicle Color"] = 'BLACK'
df.loc[df["Vehicle Color"] == "GRAY", "Vehicle Color"] = 'GREY'
df.loc[df["Vehicle Color"] == "GRY", "Vehicle Color"] = 'GREY'
df.loc[df["Vehicle Color"] == "WHT", "Vehicle Color"] = 'WHITE'

# %%
df['Vehicle Color'] = df['Vehicle Color'].replace(['YW', 'OR', 'DK/', 'GL', 'BR',
       'DKG', 'TN', 'YELLO', 'TAN', 'PR', 'WT', 'BRW', 'GOLD', 'WHB',
       'LT/', 'ORANG', 'LTG', 'WHG', 'BLG', 'GRN', 'BLW', 'MC', 'PURPL',
       'SIL', 'BRN', 'MR', 'DKB', 'YELL', 'BURGA', 'RDW', 'MULTI', 'SILV',
       'BEIGE', 'BURG', 'YWB', 'BRWN', 'LTB', 'MAROO', 'YEL', 'NOC',
       'GYB', 'GN', 'BRO', 'GR/', 'PINK', 'W', 'BL/', 'GY/', 'BKACK',
       'BN', 'BLACF', 'SL', 'BLU', 'B', 'NAVY', 'DKR', 'WHI', 'GD',
       'SLVR', 'R', 'TN/', 'BKW', 'BURGU', 'WHO', 'DKT', 'BWN', 'ORG',
       'MAR', 'LT BL', 'SIVLE', 'BURGY', 'SILVR', 'GYG', 'BK/', 'WHIT',
       'DKM', 'WH/', 'SLV', 'GRAU', 'WHTIE', 'LTT', 'RD/', 'G', 'NO',
       'BLCK', 'WT/BL', 'LAVEN', 'DKP', 'GYW', 'RDY', 'ORW', 'YL', 'BIK',
       'GARY', 'RDB', 'GRW', 'BW', 'TNG', 'GLD', 'WHR', 'BLB', 'BUE',
       'BUR', 'BKG', 'BLAK', 'RDG', 'WHTE', 'B/K', 'BR/', 'OK', 'OR/',
       'GRB', 'TNR', 'BKR', 'BLACL', 'SILEV', 'MARON', 'BX', 'YLW',
       'TEAL', 'GREEB', 'MRW', 'RUST', 'BKJ', 'PK', 'WHY', 'LTY', 'BRONW',
       'WHIET', 'GRE', 'WH/RD', 'CHAMP', 'SLIVE', 'BIEGE', 'BLAC', 'GL/',
       'MA', 'B LAC', 'GREN', 'RED/B', 'ORAN', 'RFD', 'BRT', 'BLL',
       'NAROO', 'WHIE', 'GRG', 'GRA', 'CREAM', 'DARK', 'ORENS', 'OREG',
       'SH', 'YBLUE', 'SI', 'RDT', 'BROW', 'BLE', 'MARRO', 'BLAKC', 'YW/',
       'BLUR', 'SILVG', 'BKT', 'PURP', 'SLVER', 'JEEP', 'GK', 'OLIVE',
       'WTH', 'ORB', 'BKB', 'ILVER', 'DKGRE', 'GRT', 'DBLUE', 'MRG', 'RE',
       'GYT', 'CHARC', 'SLR', 'WITE', 'YEL,L', 'TNB', 'BLUE','GREEN', 'RED', 'BROWN',
       'SILVE', 'BLA', 'GEY', 'WHE', 'GI', 'MELLO', 'BLKAC', 'MIXED',
       'BLIE', 'B RN', 'BUGRG', 'WHUIT', 'UPS', 'WG', 'BC', 'ZK.', 'MRN',
       'BALCK', 'OLVE', 'WH/BL', 'D/GRY', 'BM', 'AILVE', 'TW', 'GO',
       'B LK', 'MUTLI', 'BNR', 'SIV', 'WIT', 'TOWA', 'BURUG', 'RTED',
       'NLUE', 'BURGD', 'WTE', 'LT GY', 'DRK', 'WHL', 'LIGHT', 'WHIIT',
       'NAVYB', 'SILLV', 'BKL', 'SILER', 'BROWM', 'KXUS', 'GRAY/', 'BLR',
       'BLLUE', 'WMT', 'GA', 'GRET', 'SILA', 'GRYY', 'SB', 'O', 'OBK',
       'SKY B', 'YELLW', 'DK GR', 'BLULE', 'BL;K', 'BUL', 'GRDY', 'WGUTE',
       'SILE', 'FREIG', '..', 'MD', 'OTH', 'LK', 'GLB', 'BLACJ', 'H.M',
       'YE', 'PD', 'GP;D', 'WHT/G', 'BL/GR', 'BKK', 'SK', 'BL WT', 'TAB',
       'YWW', 'VR', 'ORAGE', 'LGT B', 'PUR', 'MAOON', 'BEIG', 'SBL',
       'BRNGO', 'RWHIT', 'WWHIT', 'PRR', 'BURUN', 'BLSIL', 'SW', 'BRON',
       'SILU', 'MARO', 'WWIK', 'BED', 'NV/K', 'RED/W', 'WHM', 'ORNAG',
       'PURPE', 'BLLK', 'BURH', 'BURGN', 'BAC', 'DKGRA', 'S', 'BEG',
       'SO;VE', 'DARKB', 'GM', 'BRPWN', 'SY', 'BLVD', 'BLUE/', 'SILVW', 'WEH', 'BGY',
       'BE', 'GREEM', 'MULT', 'BERG', 'SUR', 'BRL', 'LTBLU', 'GRAUY',
       'SILCE', 'COIO', 'GERY', 'BK/WH', 'ONG', 'BRONZ', 'WT/GN', 'BLACV',
       'WHI/G', 'NRWN', 'LT GR', 'LTP', 'JI', 'PL', 'WHITW', 'GRRY',
       'ORNEG', 'GRETY', 'BLT', 'BEIGW', 'BLKJ', 'BERGU', 'BK/GY', 'CR',
       'RD/WH', 'GREHY', 'GR Y', 'GTAY', 'ME', 'WN', 'BKYEL', 'BRU',
       'GROWN', 'MO', 'WH/GR', 'SILGV', 'RDYL', 'BKYE', 'BROOW', 'BRWON',
       'WHH', 'BWE', 'YLLW', 'SLLV', 'SIVR', 'BRK', 'BURGH', 'IK',
       'YYLLO', 'GREG', 'BRNO', 'DRKBL', 'DRKGR', 'CHREY', 'SILBE',
       'GDLD', '.', 'EH', 'III', 'ISME', 'SIVER', 'BUNG', 'WHHE', 'GOLDE',
       'PVD', 'BLAGK', 'GLG', 'WHIYR', 'MN', 'GREU', 'SIW', 'BAGE',
       'ROWN', 'GU', 'BOURG', 'LM.H', 'G/W', 'YRAY', 'SIIVE', 'LGREE',
       'D/M', 'BIUE', 'OTANG', 'OR/WH', 'BEIGI', 'GAY', 'NLACK', 'RO',
       'BRG', 'MULIT', 'ED', 'I', 'BUGUN', 'REDD', 'IW', 'RUINZ', 'BBRN',
       'TEMP', 'VARIO', 'GRAT', 'CIHI', 'GREEY', 'BRB', 'BGE', 'PNK',
       'VIOLE', 'BIU', 'YW/RD', 'WHITR', 'BEKE', 'WIU,V', 'EL', 'GYQ',
       'WTBL', 'BRUGA', 'BLC', 'CREME', 'MACON', 'REHD', 'BRUG', 'YE/RD',
       'YLN', 'BGLUE', 'DKRD', 'BREIN', 'GN/WH', 'ACURA', 'GY/BW', 'BKCH',
       'NRN', 'GLT', 'MAVEN', 'BTH', 'DIK', 'MITSU', 'BBWN', 'YZR',
       'WHT/O', 'MARN', 'PLE', 'NROWN', 'SYLVE', 'BURGE', 'BLEU', 'BR/GD',
       'REAR', 'GRN/W', 'GRU', 'MUTIL', 'YOU', 'BKRD', 'BROWB', 'WM',
       'CM', 'BRY', 'DE', 'WHBL', 'WH BL', 'SIOLV', 'GAN', 'BNLAC', 'LTR',
       'VBROW', 'GEN', 'PIK', 'CRY', 'BL/WH', 'GIL', 'GOL', 'GY/SI',
       'BERGE', 'Y', 'B;ACK', 'DIRTY', 'WHII', 'SIER', 'DK RD', 'BLACC',
       'TED', 'WH BE', 'VK', 'ORNG', 'DARKG', 'GLW', 'GTREY', 'WH BK',
       'SC', 'WLI', 'LEXUS', 'YEELO', 'HY', 'H', 'FRIGH', 'REDTA',
       'B LUE', 'S/V', 'GR/BL', 'GRY/W', 'WHITY', 'WHBK', 'MLC', 'WJIRE',
       'BGROW', 'PLUM', 'YLL', 'PRW', 'SLI', 'L/GRN', 'C', 'BA', 'TA',
       'OGLD', 'ON', 'WHIIE', 'M/C', 'BRIDG', 'BY', 'INTL', 'SV', 'BRD',
       'GRYA', 'GRAYT', 'BKN', 'GRV', 'B L', 'FREEN', 'BURN', 'WHUTE',
       'BIN', 'CHROM', 'ORGE', 'WI', 'UW', 'DARBL', 'B/G', 'GOLD/', 'BG',
       'WHIRT', 'AZ', 'BUREY', 'PAN', 'BNK', 'CIS', 'VOLVO', 'WHAT',
       'ORA', 'GDBN', 'BADGE', 'LT BR', 'C.OIO', 'GREEE', 'GYY', 'VKJ',
       'ORABG', 'REE', 'CO', 'B;ACL', 'RAINB', 'BLAKE', 'BI', 'BOWN'],'OTHER')

# %%
df['Vehicle Color'].unique()
# Out:
# array(['OTHER', 'BLACK', 'GREY', 'WHITE'], dtype=object)

# %%
df.groupby(['Vehicle Color'])['Vehicle Color'].count().sort_values(ascending=False)
# Out:
# Vehicle Color
# OTHER    243877
# WHITE    240666
# BLACK    159944
# GREY     155513
# Name: Vehicle Color, dtype: int64

# %%
df['Registration State'] = df['Registration State'].replace(['AL', 'SC', 'MN', 'PA', 'IN', 'CA', 'WY', 'OR',
       'CT', 'TX', 'MA', 'ON', 'AZ', 'DE', '99', 'NC', 'MD', 'ME', 'IA',
       'GA', 'FL', 'TN', 'RI', 'IL', 'MI', 'VT', 'UT', 'OH', 'NM', 'QB',
       'WA', 'OK', 'CO', 'MO', 'NH', 'ID', 'AR', 'KS', 'MT', 'WV', 'LA',
       'MS', 'KY', 'WI', 'HI', 'DC', 'DP', 'SD', 'AB', 'GV', 'NV', 'NE',
       'NS', 'AK', 'ND', 'MB', 'BC', 'NB', 'PR', 'NT', 'PE', 'SK', 'FO',
       'MX'],'OTHER')

# %%
df.groupby(['Registration State'])['Registration State'].count().sort_values(ascending=False)
# Out:
# Registration State
# NY       618968
# OTHER    101573
# NJ        74045
# VA         5414
# Name: Registration State, dtype: int64

# %%
df['Plate Type'] = df['Plate Type'].replace(['SRF', 'OMS', 'OMR', 'VAS', 'CMB', 'MOT',
       'APP', '999', 'TRC', 'IRP', 'RGL', 'OML', 'TRA', 'CMH', 'ITP',
       'ORC', 'DLR', 'TRL', 'MED', 'SCL', 'SPO', 'ORG', 'TOW', 'SEM',
       'CSP', 'PHS', 'MCL', 'HIS', 'HAM', 'PSD', 'SRN', 'CBS', 'AYG',
       'AGR', 'LTR', 'BOB', 'SPC', 'CME', 'CHC', 'OMV', 'SOS', 'AGC',
       'NLM', 'OMF', 'RGC', 'THC', 'NYC', 'NYA', 'MCD', 'PPH', 'WUG',
       'GSM', 'ARG', 'AMB', 'CCK', 'HIR', 'LMA', 'BOT', 'ATD', 'LMC',
       'STG', 'NYS', 'GAC', 'USC', 'LUA', 'ORM', 'OMO', 'CLG', 'FPW',
       'VPL', 'FAR', 'SUP', 'STA', 'HAC', 'JSC', 'ATV', 'USS', 'LMB',
       'JCL'],'OTHER')

# %%
df.groupby(['Plate Type'])['Plate Type'].count().sort_values(ascending=False)
# Out:
# Plate Type
# PAS      576153
# COM      159634
# OTHER     36166
# OMT       28047
# Name: Plate Type, dtype: int64

# %%
df['Vehicle Body Type'] = df['Vehicle Body Type'].replace(['REFG','SDN', 'TAXI', '2DSD',
       'TRAC', 'UTIL', 'PICK', 'CONV', 'P-U', 'FLAT', 'BUS', 'MCY', 'TLR',
       'TR/C', 'TRLR', 'TRUC', 'TRAI', 'TR', 'DUMP', 'TANK', 'I', 'SEMI',
       'SEDN', 'T/CR', 'TK', 'MCC', 'INTE', 'SWT', 'MOT', 'STAK', 'TWOD',
       'A', 'TRT', 'TOW', 'BOAT', 'TRC', 'FOUR', 'LTRL', 'BS', 'MC',
       'MOBL', 'LIM', 'S/SP', 'H/WH', 'CONT', 'TRK', 'MOTO', 'SCHO',
       'TRAL', 'BIKE', 'H/TR', 'TRL', 'TT', 'TL', 'REFR', 'T', 'TKR',
       'P/SH', 'SN/P', 'RL', 'WAGO', 'WIS', 'II', 'FIAT', 'FREI', 'POLE',
       'TRIL', 'NS', 'RV', 'TCR', 'PURP', 'SUV', 'TR/E', 'APP', 'UHAU',
       'N', 'TEOD', 'REFT', 'CUST', 'DAMP', 'KIA', 'W/DR', 'SEM', 'BLAC',
       'MINI', 'UTLT', 'COM', 'TAIL', 'LIMO', 'COUP', 'PAS', 'HINO',
       'CMIX', 'TWOS', 'TTRA', 'FPM', 'MS', 'HRSE', 'WHIT', 'SEMT',
       'JGBR', 'TRAV', 'OMS', 'JEEP', 'TML', 'TRA', 'ARMO', 'RLL', 'H/IN',
       'UPS', 'CONU', 'TOWT', 'DELI', 'TUW', 'NE', 'VESP', 'R/RD', 'SCOO',
       'OMR', 'VAS', 'CYL', 'POWE', 'EMVR', 'TNI', 'BOXT', 'ACTO', 'UT',
       'R', 'VANT', 'MYC', 'ILQ', 'TRTL', 'QFIV', 'TNT', 'EVAN', 'REF',
       'RHOD', 'COUE', 'TTR', 'O', 'RPLC', 'TRUV', 'TRNC', 'FORD', 'MACT',
       'FORE', 'STRE', 'GRAY', 'REFE', 'BVER', 'REG', 'HRIN', 'RED', 'L',
       'BK', 'HWH', 'CB', 'APPO', 'IU', 'F', 'TWO', 'LIGH', 'NIS', 'TOYO',
       'MORT', 'CNWV', 'GY', 'PETE', 'S', 'D', 'MOPE', 'NAA', 'WORK',
       'AJIS', 'CARC', 'NER', 'SD', 'IZ', 'COOM', 'KW', 'ACUR', 'LLL',
       'VONV', 'NRL', 'REFH', 'MCB', 'LI', 'AN', 'IL', 'DEMI', 'TAG',
       'RI', 'ACCO', 'SRF', 'RT', 'TDSD', 'ASL', 'KENW', 'AO', 'COLO',
       'TRKT', 'V', 'JRZO', 'IIR', 'CHRY', 'IJ', 'JOOO', 'SMAR', 'MURA',
       'FEL', 'TLCR', 'RN', 'MORO', 'UNIL', 'VAND', 'TC', 'RECR', 'CROS',
       'LSV', 'TRUM', 'UTL', 'ZDSD', 'RD/S', 'UITL', 'TON', 'WACA', 'RAC',
       'GREE', 'SCOD', 'IRN', 'DOOR', 'FRE', 'COMM', 'DETA', 'DELA',
       'TRI', 'ICEC', 'RUDE', 'NLH', 'YDSD', 'LLT', 'FRHT', 'MP', 'WSR',
       'REFI', 'SIMI', 'CL', 'TAW', 'ILQT', 'REFS', 'PEDI', 'TRR', 'TRCT',
       'SEDA', 'ILIM', 'NU', 'P', 'SM', 'RM', 'NLR', 'COUR', 'ELR',
       'UTIC', 'GRY', 'TLK', 'FREG', 'ERL', 'TFR', 'HIGH', 'LINO', 'UTI',
       'FLEE', 'LL', 'ZL', 'BOB', 'RMT', 'YICI', 'BUSY', 'E', 'COOP',
       'GRAN', 'NL', 'MOPC', 'CV', 'LLR', 'RA', 'TOWD', 'INRN', 'MIFU',
       'TACT', 'DEL', 'HX', 'TREC', 'SPOR', 'LRZL', 'TART', 'FEDE', 'BT',
       'HYUN', 'CON', 'TRCK', 'RBM', 'SUBA', 'HATC', 'YD', 'SCL', 'CRV',
       'RNCR', 'WB', 'OODO', 'NJ', 'SW', 'NNM', 'SCOM', 'TRLT', 'CONX',
       'UHAL', 'IA', 'SPRI', 'TPK', 'NIJ', 'WHEE', 'UNTI', 'ZDS', 'BU',
       'STAW', 'BUG', 'TRAT', 'TOWL', 'TRLC', 'OOOO', 'SILV', 'WINN',
       'VTRU', 'NM', 'TARC', 'CAMR', 'W/SR', 'GARB', 'WH', 'DELT', 'HILO',
       'EIGH', 'NAIL', 'MCL', 'OOPO', 'TRYO', 'AOOO', 'RF', 'IN', 'LR',
       'TI', 'LIDD', 'ITRA', 'MH', 'DEMA', 'NLS', 'LARO', 'TIT', 'COVN',
       'MI', 'TMIR', 'INIS', 'AUTO', 'MWV', 'CP', 'SXYN', 'PORS', 'UD',
       'CLAS', 'OL', 'CALI', 'CEME', 'REBS', 'FDSD', 'IT', 'TRAE', 'M',
       'NSN', 'IG', 'TRAN', 'FOUU', 'DOZE', 'RFG', 'MCT', 'IML', 'APUR',
       'MRSE', 'TAN', 'NLL', 'ILN', 'PU', 'CUBC', 'PK', 'MCX', 'BR',
       'IRP', 'TICR', 'LOCO', 'PKKU', 'REFA', 'UTHA', 'DIRT', 'STAC',
       'AI', 'SAMR', 'OML', 'Q', 'TVA', 'BOS', 'RETO', 'BLIB', 'TTI',
       'TRLE', 'YDTO', 'HTR', 'TRAF', 'WGN', 'PUP', 'RJH', 'TOLL', 'BROW',
       'VANH', 'TRAY', 'NH', 'BOXD', 'RLT', 'STAT', 'LMC', 'LINC', 'DEAL',
       'JRJS', 'TRLF', 'NI', 'BLUE', 'HHB', 'ILL', 'IM', 'CR', 'MCI',
       'BOXV', 'G', 'NN', 'OSAV', 'INFI', 'US', 'MOBI', 'UTIZ', 'RGL',
       'TX', 'OSAT', 'SCIO', 'DSD', 'SI', 'REDF', 'MAI', 'AIM', 'CARG',
       'TRAK', 'EH', 'SJL', 'MOTM', 'III', 'TLC', 'NLIJ', 'ESTH', 'BWCK',
       'FORK', 'BACK', 'CT', 'MR', 'FREB', 'RBOO', 'BUMP', 'REB', 'BUSN',
       'RAM', 'LRAL', 'ZM', 'ISUZ', 'TOUD', 'CARH', 'TET', 'TJ', 'BVS',
       'WBN', 'BOX', 'TRCU', 'TAHO', 'FPTP', 'VM', 'BLK', 'SUBR', 'NK',
       'FRIE', 'STAR', 'REFQ', 'CAB', 'SNV', 'LRQ', 'U', 'VTE', 'HOUS',
       'IJN', 'QQGO', 'DI', 'DE', 'SUKU', 'TRUE', 'HRST', 'UDSD', 'EL',
       'WHIL', 'TRTR', 'MCSC', 'JRL', 'TWDS', 'ITTN', 'HDSD', 'C', 'COMT',
       'ANTI', 'MW', 'HOND', 'NII', 'TRAU', 'GFQO', 'VZO', 'TF', 'NNSM',
       'AJ', 'PREV', 'NGN', 'TWOT', 'SEMF', 'FB', 'MEFG', 'LIVE', 'LONO',
       'RETG', 'WALO', 'MN', 'SL', 'MOF', 'BUDG', 'THAC', 'BL', 'REAR',
       'RHU', 'IJI', 'IS', 'ITR', 'MCV', 'OMT', 'OTN', 'TROL', 'GJNI',
       'APPA', 'NLC', 'ALL', 'SPEC', 'IINI', 'DELW', 'CAMP', 'CONS', 'IR',
       'UPST', 'UYIL', 'SAC', 'IRAC', 'CABT', 'KEVG', 'RVMO', 'BUSV',
       'HENY', 'SE', 'NUS', 'GMSX', 'ID', 'DLU', 'TAT', 'VERB', 'OAZO',
       'BLOC', 'STWA', 'IJDW', 'TRU', 'BKAC', 'WHT', 'ATV', 'BUST',
       'ONGO', 'B', 'TRE', 'REI', 'INN', 'W', 'MEY', 'NW', 'MOPD', 'STJ',
       'BIUS', 'PIUT', 'H', 'VOLV', 'ELEC', 'RE', 'TRIC', 'TCK', 'CAP',
       'TNK', 'Z', 'FRET', 'BCS', 'GMC', 'WEN', 'MSL', 'INT', 'MERC',
       'TRCA', 'NYC', 'NIA', 'OMNI', 'MOY', 'BXTR', 'ALTM', 'CRUZ',
       'MOVI', 'DEW', 'MDX', 'PV', 'TNUC', 'LCOM', 'RG', 'VI', 'MUPL',
       'TAC', 'NLSN', 'FNZU', 'FREK', 'HOWH', 'SLL', 'MD', 'SN', 'PASS',
       'VOLN', 'SAMI', 'RWLS', 'TRRT', 'NAI', 'APPT', 'CDNV', 'BUSS',
       'NTIL', 'PFTR', 'UNK', 'MOC', 'AMOR', 'RNN', 'OMIB', 'LIN', 'LJI',
       'UTD', 'UNIT', 'TRWH', 'COAC', 'LTR', 'AA', 'NJTR', 'MTO', 'ZOIS',
       'IIM', 'MACK', 'TNZC', 'RIGG', 'WANT', 'BYS', 'INDM', 'ED', 'ZUHE',
       'Y', 'MLT', 'TIZM', 'RIG', 'ORFR', 'MCIY', 'TRLA', 'OMTE', 'BELV',
       'GREY', 'IITN', 'IAFN', 'HSDH', 'WL', 'NMOT', 'SOBN', 'SRN',
       'OOBS', 'RHYC', 'BURG', 'SS', 'NRR', 'DDOR', 'AP', 'LN', 'ALLS',
       'SUZU', 'AL', 'OODI', 'JUEH', 'TRUI', 'SV', 'CA', 'QUEB', 'NAW',
       'DEIV', 'GOV', 'NR', 'RCF', 'COME', 'TIRA', 'AR', 'IY', 'TNAC',
       'TMIL', 'MASD', 'TROC', 'NZI', 'HAMP', 'ILM', 'RANG', 'HIWH',
       'OSW', 'SX', 'ROCK', 'TRAA', 'WOR', 'TNL', 'INCK', 'VYS', 'SA',
       'FRDI', 'STRI', 'TEXA', 'MITS', 'SUBU', 'FORN', 'BTRU', 'CYLE',
       'ILIN', 'RARO', 'MOTQ', 'IRLC', 'REFD', 'BOST', 'TMCK', 'IE',
       'CHEV', 'SOUT', 'NIN', 'CROV', 'FTTR', 'ILLI', 'ZIL', 'MONI',
       'ILA', 'WS', 'CAR', 'TIMO', 'ROW', 'HARL', 'DWMP', 'TCAC', 'SAU',
       'THE', 'CJOR', 'CAMB', 'INL', 'SHGR', 'MEF', 'TRTE', 'ZADF',
       'COWX', 'JOO', 'DEVI', 'FBTR', 'QGYP', 'JAML', 'INTL', 'ERN',
       'MAYM', 'YDSO', 'TYAI', 'RET', 'RD', 'GK', 'CADI', 'CRAN', 'AC',
       'REFY', 'TRJU', 'NAC', 'FLAG', 'TAX', 'UDXR', 'TREE', 'CD', 'FRID',
       'MTC', 'CARA', 'BNS', 'FRGH', 'POST', 'SNNI', 'IXI', 'BJS', 'PTF',
       'CHAR', 'MIGH', 'CO', 'JLGL', 'CMV', 'MOPG', 'SAI', 'ES', 'DU',
       'JKAC', 'MAXI', 'ILLL', 'CHX', 'OO', 'HACK', 'TOWF', 'TRUK',
       'OOPS', 'YASO', 'HI', 'TRIA', 'ME', 'RERI', 'AYS', 'AS', 'FURE',
       'RCAI', 'MOTE', 'ORPP', 'WHN', 'HEAR', 'PIAC', 'SR', 'HLLD', 'TP',
       'NVJ', 'FIVE', 'TRRA', 'TRN', 'TRLQ', 'RNIT', 'FG', 'FONT', 'MT',
       'TRX', 'RR', 'TRUJ', 'WHI', 'COMN', 'VANF', 'PA', 'REEF', 'FRIG',
       'TPC', 'NYSD', 'HD', 'CONY', 'EEP', 'TARI', 'ELEM', 'CUEC', 'AMB',
       'EN', 'WREC', 'NJS', 'FALT', 'NNO', 'WI', 'TRTA', 'WLL', 'DECT',
       'TIAC', 'TRAG', 'DP', 'DMP', 'PAIX', 'SUB', 'CORV', 'ISUS', 'NEIS',
       'GR', 'DECR', 'TEL', 'COUN', 'CIVI', 'RAFG', 'IYXK', 'TLB', 'URII',
       'TEMP', 'THRE', 'COPU', 'MOTR', 'QPSP', 'DIPL', 'COV', 'TEAI',
       'RS', 'OMB', 'TLAD', 'UNNT', 'X', 'BIOX', 'UTRL', 'CYCT', 'UMAH',
       'KAWA', 'PLUM', 'VOLK', 'DELU', 'ANA', 'BOXF', 'CPUP', 'BUSF',
       'REGR', 'REGF', 'FR', 'UTLI', 'CAN', 'TTL', 'NRN', 'IRD', 'STER',
       'CU', 'RII', 'FRLI', 'ORG', 'TENT', 'KE', 'TRIR', 'ERLK', 'VAHO',
       'RAMP', 'REFO', 'TAL', 'MILR', 'ZDIZ', 'RETR', 'TRML', 'SETA',
       'TRIT', 'CDNU', 'RNL', 'ERLI', 'BIK', 'PLAT', 'SCFF', 'COMP',
       'VNTR', 'CUAV', 'MEME', 'OFNG', 'FODR', 'DLN', 'TCTO', 'BB',
       'UILI', 'LB', 'DVEL', 'MAZD', 'FRI', 'JNIL', 'NPP', 'STEE', 'SERM',
       'TUK', 'RIR', 'TOWN', 'MTR', 'UTLL', 'YK', 'MUHU', 'NMI', 'MPV',
       'GEML', 'UZC', 'MNIS', 'MB', 'IRPT', 'FIS', 'TREA', 'NCIC', 'KJJ',
       'GMT', 'UITI', 'MTIL', 'MOPO', 'YVJR', 'BUB', 'ARNO', 'ULL',
       'HEAV', 'CYCL', 'SONA', 'IYYJ', 'TM', 'ODOO', 'REVG', 'CJTI',
       'YAMA', 'RACK', 'BUA', 'HCK', 'CI', 'CDMT', 'JI', 'ETDE', 'CAME',
       'TRYC', 'JII', 'EOTL', 'RZTE', 'SPR', 'IMVK', 'FRTT', 'LSD',
       'SLIV', 'LNRR', 'TKIW', 'GTRA', 'FLM', 'COMI', 'TDOO', 'FRL',
       'TOSO', 'OA', 'OMBB', 'SG', 'FREU', 'YELL', 'OUMP', 'COND', 'BOYT',
       'MARY', 'MIC', 'GEOR', 'JO', 'INNI', 'IB', 'BGSO', 'SEML', 'SUGN',
       'LT', 'BIS', 'OOO', 'RENW', 'DUMD', 'YDOO', 'PS', 'MISA', 'BLU',
       'HAUL', 'RHL', 'BE', 'BSD', 'SCOT', 'BOOM', 'MEBE', 'REFC', 'KJ',
       'DUNY', 'GREA', 'HII', 'THK', 'DRU', 'RENT', 'CCUE', 'CARR', 'RSE',
       'NICY', 'JJOO', 'IKDF', 'RERE', 'FUVA', 'MCU', 'CH', 'HONE',
       'BEFG', 'IVU', 'TFH', 'LIFT', 'MORN', 'RNO', 'IMXN', 'CN', 'OAW',
       'MCYC', 'TAK', 'MHWH', 'IZTR', 'PL', 'TRUN', 'HOU', 'PIN', 'COYR',
       'NISS', 'FREH', 'SNA', 'LIIA', 'TOWC', 'INR', 'HW', 'TLT', 'JGOF',
       'OOAP', 'ROOV', 'IMC', 'ENI', 'OR', 'RWRO', 'TOWO', 'UTIU', 'REPG',
       'STNK', 'OHIO', 'USPS', 'LEXU', 'UHI', 'TACR', 'GDS', 'BINE',
       'MOFO', 'J', 'NTRJ', 'BEDG', 'SABT', 'ALTI', 'CIDE', 'EO', 'POO',
       'TKL', 'YKK', 'STAL', 'BOOK', 'AMBU', 'COMB', 'JETT', 'STRA', 'MJ',
       'MALI', 'SUBC', 'HTBK', 'NLF', 'SPC', 'AMMO', 'FRAC', 'RLLR',
       'FIGT', 'LLK', 'MOR', 'UPG', 'ULTI', 'TTT', 'INDI', 'RTR', 'UBSD',
       'WEST', 'FOOR', 'RSL', 'NAN', 'AII', 'BOXR', 'TMEL', 'TPLR',
       'TDSP', 'AOSD', 'THL', 'NTL', 'REP', 'BLBI', 'TILE', 'FLBD', 'UNL',
       'MASC', 'FOUD', 'RW', 'CPE', 'UNIV', 'MFIV', 'CYC', 'QR', 'TRCR',
       'UTIK', 'COUV', 'UTZL', 'VANB', 'FRTL', 'SUU', 'ALR', 'DRLR',
       'DCOM', 'URIL', 'RERG', 'PLUT', 'TRLK', 'TYRA', 'REC', 'ATS',
       'NTY', 'CHH', 'BRN', 'MARK', 'TOLO', 'DZAL', 'DUIM', 'HC', 'REFN',
       'FKAT', 'GONV', 'NLNL', 'ONE', 'DN', 'GE', 'MAPE', 'MCIB', 'YWOD',
       'IP', 'STW', 'ALAB', 'SII', 'MBRU', 'WHOR', 'FTAS', 'EXPR', 'GLAT',
       'ZS', 'BMW', 'DUM', 'JAGU', 'PZ', 'BLES', 'IFQS', 'CAUP', 'LAI',
       'PREF', 'RP', 'FLBE', 'MAGN', 'LA', 'STEP', 'SUT', 'NCY', 'CS',
       'TRAD', 'IIII', 'SWV', 'LLI', 'CUOI', 'DLVT', 'RGF', 'TIME', 'FRG',
       'ZD', 'SABN', 'OCPO', 'GLL', 'MTRC', 'HWM', 'PI', 'RZIR', 'NNN',
       'OOCD', 'IZLI', 'FREF', 'ELN', 'YRAC', 'WISC', 'BUIC', 'GLAS',
       'OIAI', 'DLV', 'TURC', 'TA', 'VA', 'SPEA', 'HET', 'RIFR', 'RALL',
       'WT', 'EBIK', 'PIU', 'UH', 'ARNM', 'VSI', 'TN', 'WINH', 'OPEN',
       'INNL', 'NOTS', 'TDAI', 'SSOO', 'OFF', 'VIS', 'SBN', 'YEBU', 'MEN',
       'SMAE', 'TRCL', 'TRQI', 'UTTL', 'BULL', 'LONV', 'BBR', 'MONG',
       'TNC', 'TRAM', 'DELO', 'TRAZ', 'NCS', 'KENT', 'VNT', 'RH', 'VN',
       'COMA', 'AE', 'ILZN', 'AIC', 'WAN', 'DEVL', 'SEME', 'LLM', 'IKL',
       'DICK', 'TRLS', 'KEFG', 'IW', 'MK', 'UHL', 'TTRL', 'ORL', 'FIAL',
       'UN', 'WON', 'CITY', 'CMX', 'NNU', 'NSI', 'PETR', 'NSDN', 'VERI',
       'ISI', 'SUEL', 'CHIX', 'PLU', 'TRLL', 'FRT', 'INS', 'AHIN', 'AUDI',
       'IISI', 'TRY', 'RRIC', 'ONN', 'NNNI', 'CROB', 'NNRI', 'OIFU',
       'FES', 'UI', 'IISC', 'MACE', 'CPNV', 'YDSL', 'VS', 'VDJI', 'TRAO',
       'JAN', 'EC', 'LIIN', 'FTWH', 'ERR', 'TCTR', 'BARX', 'PONT', 'ATLK',
       'IRII', 'IIWU', 'MCYT', 'PTCR', 'SNN', 'RRSR', 'IMST', 'IIIJ',
       'TLRL', 'BUD', 'OBSI', 'IRJI', 'RNRR', 'SIID', 'FRUZ', 'ZSS',
       'SIII', 'TESI', 'PQPI', 'TRMW', 'UTAL', 'FDSO', 'ENVO', 'COVE',
       'GOLD'],'OTHER')

# %%
df['Vehicle Make'] = df['Vehicle Make'].replace(['MITSU', 'INTER', 'FRUEH', 'KENWO', 'VOLKS',
       'DODGE', 'CHEVR', 'LINCO', 'VOLVO', 'HIN','GMC',
       'ME/BE', 'AUDI', 'JEEP', 'CHRYS', 'CADIL', 'INFIN', 'ACURA',
       'LEXUS', 'BMW', 'KIA', 'HYUND', 'ROVER', 'UPS', 'SMART', 'SCION',
       'NS/OT', 'SATUR', 'STAR', 'SUBAR', 'PETER', 'ISUZU', 'BSA',
       'MAZDA', 'HINO', 'OLDSM', 'YAMAH', 'AM/T', 'PONTI', 'PORSC',
       'UTILI', 'MI/F', 'UD', 'BUICK', 'GMCQ', 'CITRO', 'JAGUA', 'MERCU',
       'SAAB', 'PLYMO', 'SPRI', 'WORKH', 'GEO', 'TESLA', 'KAWAS', 'MINI',
       'MACK', 'VESPA', 'WORK', 'TRAIL', 'STERL', 'GRUMM', 'HUMME',
       'FIAT', 'SUZUK', 'CARAV', 'TRIUM', 'TLR', 'IC', 'KI/M', 'BERTO',
       'VANHO', 'ADD', 'FREIH', 'KNL', 'MASSA', 'ADI', 'FRHLI', 'CHECK',
       'HYUN', 'MERC-', 'MICKE', 'HARLE', 'ANCIA', 'FRL', 'FRIEG',
       'AUDI3', 'JENSE', 'BL/B', 'FERRA', 'INFIT', 'UTIL', 'VAN H',
       'DUCAT', 'FLAI', 'HIGHW', 'MASE', 'DORSE', 'ROLLS', 'GREAT',
       'BL/BL', 'FUSO', 'THOMA', 'NAVIS', 'LAYTO', 'SUNBE', 'PREVO',
       'GREIG', 'KW', 'FEDEX', 'HO/R', 'FONTA', 'SATU', 'WANC', 'RO/R',
       'WO/H', 'STRIC', 'OKIA', 'F/L', 'BENTL', 'UNIV', 'FRLN', 'MAGIR',
       'EVERE', 'PREV', 'TESL', 'MCI', 'HUMBE', 'WO/C', 'LICOL', 'RA/LA',
       'FRIE', 'GRT', 'KENTU', 'BL/BI', 'BRUTA', 'VANGU', 'LA RO',
       'FR/LN', 'STUDE', 'MER', 'PEUGE', 'FRLT', 'HOME', 'CARGO', 'HERCU',
       'BUIIC', 'FRIG', 'WO/CH', 'SOLEC', 'GIDNY', 'EASTO', 'FUSIO', 'P',
       'HYV', 'EAST', 'TRA', 'ALFAR', 'FR/LI', 'FRG', 'YIAN', 'CIMC',
       'MI/JO', 'KENW', 'REFG', 'TRUCK', 'UT/M', 'S HEN', 'CLD', 'WH',
       'VESLA', 'MG', 'AUSTI', 'WHITE', 'SUK', 'THEUR', 'ZUMA', 'LAQND',
       'GSC', 'ITNE', 'SOLE', 'ISZUK', 'GENES', 'VLKSW', 'RENAU', 'VHOOL',
       'CUBCA', 'DIAMO', 'STARC', 'ROLDA', 'WINN', 'GIO', 'WRK H',
       'FISKE', 'EAGER', 'UNIFL', 'PB', 'MEI', 'MACDA', 'WKHS', 'SKODA',
       'ABART', 'AMTIR', 'MAYBA', 'GOV', 'AAUDI', 'AMC', 'SMITH', 'PET',
       'TITAN', 'SERR', 'RA/LO', 'DEMA', 'BLUE', 'FRD', 'KENT', 'PONTU',
       'INIFI', 'POIN', 'LEIS', 'CABC', 'FHTL', 'LAND/', 'CUB C', 'COLTI',
       'KENOW', 'JEEPW', 'HUN', 'KEN W', 'HUDI', 'MAXON', 'WHOR', 'FN/L',
       '3ULCK', 'LOTUS', 'OSHKO', 'FC', 'VA/H', 'GENIS', 'LAMBO', 'GDAVE',
       'FRET', 'WPS', 'AUTOC', 'LA/LO', 'MISU', 'UT MA', 'PROS', 'BRIDG',
       'TRIM', 'CAIRO', 'FR LI', 'FRTL', 'VPG', 'NEWF', 'FR', 'BLUEB',
       'FREG', 'NEWM', 'PORSO', 'DATSU', 'TELSA', 'FIBE', 'R ROV', 'HUD',
       'FOUR', 'MI FU', 'AGUND', 'PAR/S', 'NEURA', 'FL', 'FRIGH', 'INTIN',
       'JAMB', 'FR/L', '24LIL', 'TOMOS', 'FR-L', 'ELDO', 'WRKHO', 'FRGHT',
       'FRT C', 'CHER', 'UTIC', 'CROWL', 'STRA', 'MWV', 'RO', 'HYDI',
       'G D', 'FONA', 'FRITH', 'RED', 'UTI', 'EUIG', 'FR/LT', 'KIIA',
       'W/GM', 'FRIN', 'HINO.', 'WABAS', 'TORRE', '7MM', 'WO HO', 'AERO',
       'FR L', 'PREO', 'NS', 'MERA', 'FRT', 'FRGH', 'ME/BR', 'AMTR',
       'APPAL', 'OMR', 'VNHL', 'TEBLA', 'GRUEH', 'LANTO', 'DAEWO', 'OMST',
       'MINIC', 'CUB', 'WRKHS', 'ASTMA', 'BIKE', 'MESAR', 'DUCCT',
       'TESCA', 'MIFI', 'MONON', 'FREVO', 'GRDN', 'FREI', 'AM/TR',
       'BUZCK', 'TLP', 'AS/M', 'INTEL', 'TRLR', 'MUZDA', 'EZL', 'FL/LR',
       'AUS H', 'NEW', 'ENDRI', 'SUBA', 'VOKSW', 'N7S', 'WKH', 'KENIL',
       'V.W.', 'HAD', 'PICK', 'CHSTL', 'GD', 'H/D', 'FRTLI', 'PIAGG',
       'CHNEN', 'ISUA', 'KRNWO', 'UTIAL', 'SPARC', 'WORKD', 'FRH', 'BGTI',
       'JMH', 'GILL', 'SPRIA', 'FRFIG', 'TRAC', 'APRKI', 'WCC', 'ACB',
       'LADA', 'ACURR', 'SHINO', 'TTR', 'SNUN', 'N', 'MOTOR', 'SE/RA',
       'UHAUL', 'WAB', 'SMARY', 'UTILL', 'HUNN', 'UT', 'FERIG', 'PETE',
       'ENFIE', 'COBUI', 'HART', 'GRE', 'EAS', 'MITS', 'MIDA', 'WATAS',
       'FIATL', 'VANH', 'GSB', 'SOLEA', 'BUDD', 'HYTR', 'CYSL', 'HIND',
       'PROVO', 'FAE', 'COMME', 'MREC', 'HACKN', 'MORGA', 'SURB', 'MCRY',
       'WABA', 'FT/L', 'H', 'WO/HO', 'XLSP', 'MC/BS', 'TRITO', 'DELOR',
       'TRUMI', 'RANG/', 'TI BR', 'WHCC', 'WKHRS', 'GREIC', 'HYUAN',
       'NIR', 'MV1', 'IL', 'REVO', 'INTR', 'COBCA', 'WORKE', 'R/R',
       'CA/TR', 'UNKNO', 'SUGN', 'ACYRA', 'WRKHK', 'TRL', 'UFILM', 'HUYD',
       'KEWWO', 'LA-RO', 'OUTL', 'SUZU', 'ENTTE', 'INTI', 'CHEET', 'FRGI',
       'WHORS', 'DURAP', 'POACH', 'STAUR', 'HERCE', 'ZENIT', 'AL/R',
       'KINMO', 'CHAM', 'MAIME', 'LARGO', 'COLL', 'HUDAI', 'FREHT',
       'PORTJ', 'FTLIN', 'YUGO', 'COM', 'VAN', 'IMFIN', 'HA/D', 'MAZO',
       'FEIGH', 'TNT', 'LLINO', 'MASTE', 'MI/IA', 'BIG B', 'W/A', 'MCA',
       'AUDL', 'FTLI', 'ROLAN', 'INER', 'FRGL', 'HUME', 'STELL', 'WORKM',
       'VOLK', 'BWN', 'RA/RO', 'LO/RO', 'SYERL', 'GNC', 'GDAL', 'AJAX',
       'UNIVE', 'OLDM', 'BERIN', 'DEL', 'REFRE', 'OLDMO', 'FTLR', 'TW',
       'GRAND', 'CRYST', 'OIDSM', 'WANE', 'FRIL', 'PGO', 'VANI', 'FT/LI',
       'FRI', 'MAZLA', 'MERUS', '1', 'NLS', 'WRK', 'ARGOS', 'TRTL',
       'WOIKH', 'FRLNR', 'HINI', 'HYYN', 'UBS', 'KAUFM', 'AXAT', 'HTYUN',
       'CAT', 'R', 'COAC', 'INTEN', '09', 'DONGF', 'HUMU', 'BL HI', 'NRD',
       'SOLEE', '5UDI', 'PIA', 'KENS', 'STL', 'N/S', 'MOUST', 'MASEA',
       'JINDO', 'KINO', 'SETRA', 'PTERB', 'KAUF', 'MASEP', 'IA', 'JAUWA',
       'ANKA', 'DOTIR', 'KENIW', 'VOLJK', 'SOUT', 'MITSV', 'FREGI',
       'FREL', 'TEMS', 'MAC T', 'WKHOR', 'KRMO', 'RRV', 'VELO', 'INFNI',
       'OFUSO', 'CARSI', 'WO CH', 'WV', 'MARCU', 'UTL B', 'WOCH', 'HERCL',
       'HIUNO', 'FRHT', 'UD/N', 'PTRB', 'LA/LD', 'FDR', 'HERC', 'AL',
       'FREGT', 'KYMOO', '`', 'OLD M', 'LE', 'CHRY', 'GOJ', 'CHASS',
       'NAVS', 'TX', 'MI/DU', 'FRT L', 'CECK', 'FRLG', 'UMC', 'KENHU',
       'OACUR', 'RLYMO', 'ANAK', 'MAZD', 'RINO', 'MACKR', '3MW', 'ITNL',
       'YELLO', 'FA/L', 'SADAN', '1ZUZU', 'FREGH', 'SPENC', 'STOUG',
       'OSUZU', 'HYDY', 'BL/BJ', 'XAWK9', 'INTTE', 'Thom', 'HENO',
       'MITCH', 'FRGT', 'BUT', 'V/S', 'METRO', 'ALERO', 'WRHOR', 'LETIL',
       'FREIL', 'KEWO', 'WRH', 'VOLLS', 'ST/C', 'T4', 'Z', 'KWAS', 'B',
       'MASCA', 'CHY', 'WINNE', 'BUSI', 'HYUNO', 'SIXTU', 'UTILM',
       'GOLFS', 'TURT', 'FLEAT', 'INN', 'HYVND', 'AMTRA', 'CITC', 'CARSO',
       'SUYBA', 'PERC', 'CA/EX', 'SPEC', 'COTL', 'KENNW', 'ZYWIE',
       'PORAC', 'WYD', 'AM/G', 'ECJAR', 'VICTO', 'OPEL', 'MANAC', 'MERCH',
       'FRIHT', 'PEYMO', 'EDGE', 'OTH', 'TR/T', 'ACUDO', 'SCBAR', 'INFER',
       'CA/RO', 'BUS', 'SUIZI', 'VERIZ', 'HAC', 'CHUR', 'MCE', 'ACURO',
       'FREFI', 'JNK', 'NORKH', 'MI/FL', 'FRTLR', 'CAPPA', 'MA3', 'ALEXA',
       'CORB', 'WO/HS', 'LA/R', 'SMRT', 'GO', 'UT/MA', 'WESTR', 'BLBI',
       'ASTOR', 'NATIO', 'IJD', 'STAC', 'LND R', 'LEXUW', 'LA/RD',
       'FRELI', 'SCAN', 'FLINE', 'MERCI', 'SMAR', 'SUBUN', 'TRIST',
       'RYDER', 'BAHSA', 'CAYTO', 'GOLD', 'SMC', 'HECHT', 'METZ/',
       'FRGTL', 'NEVIS', 'HYBRI', 'MAUC', 'STEVY', 'WRHKH', 'PETET',
       'FRIT', 'LR/R', 'CHEB', 'M', 'BOUN', 'AL/D', 'SOZUK', '199',
       'TESLE', 'BOUND', 'PEDIC', 'WRK V', 'GILLI', 'MONO', 'BI', 'WORTH',
       'CHEYR', 'BRI', 'STRI', 'CONVO', 'SETON', 'THIEN', 'GREY', 'VOLX',
       'LES', 'AC', 'SIMCA', 'JNFIN', 'FROD', 'FGT', 'FREAT', 'WO/ST',
       'PANER', 'COT', 'WABAP', 'VESGA', 'PROVS', 'GREG', 'VALHO',
       'KYMCO', 'JAUAR', 'KAIA', 'MWSKI', 'GIWI', 'GRD', 'MAROO', 'PIAG',
       'QUAHI', 'JAOTA', 'KENNE', 'HACV', 'KID', 'OLDSI', 'NINJA',
       'WK/HS', 'UHAL', 'OPELP', 'RS', 'SPORT', 'POV', 'FRAUM', 'GRE D',
       'AWDRD', 'TMAY', 'PLMTH', 'SHOOP', 'TRIUN', 'HINON', 'HIRS',
       'UNCBC', 'MT FU', 'MELBE', 'MANC', 'HARVE', 'G DAN', 'FREGA',
       'UTILT', 'MCT', 'UPS D', 'CADI', 'CUST', 'JOCLN', 'MOTO', 'FFEIG',
       'GENUI', 'UBER', 'IFINI', 'HUNYD', 'BRI M', 'BARGM', 'PORTI',
       'CHELR', 'WOR H', 'TN/LI', 'FTL', 'HYDU', 'TRIV', 'GDAE', 'FREX',
       'K/W', 'FU', 'BUGAT', 'STATU', 'ORIEN', 'FFLIN', '517', 'YUKO',
       'UTLIT', 'DDERA', 'FRLI', 'FIAL', 'INEGH', 'VOLKA', 'QIDON',
       'CADC', 'WK/H', 'MADU', 'MICK', 'WE/S', 'SATRA', 'PUOC', 'KENSW',
       'TRAI', 'KENHO', 'FREIC', 'ITER', 'FRGLN', 'ETERB', 'KW3', 'YANH',
       'PONTA', 'BL', 'STRL', 'ELKD', 'FLXZ', 'KENTW', 'MU/FG', 'CHYRY',
       'EAM', 'NEVOS', 'MAZER', 'WRKHA', 'MBEN', 'SERIE', 'SUN U', 'HRC',
       'IYUNO', 'VOLLK', 'NFM', 'MAERS', 'INTEE', 'ARUCA', 'WKH T',
       'ACADE', 'THMOA', 'ALFXA', 'LL', 'APROL', 'ACRUT', 'NERC', 'FR/LA',
       'HUYN', 'JAY', 'WORKI', 'ROCK', 'FR/LM', 'HY UN', 'SRT', 'WH/G',
       'FRAT', 'IAJ', 'U/W', 'VW', 'KEW', 'YPAN', 'V HOO', 'CDET',
       'UD TR', 'HUNER', 'UNHL', 'USEZU', 'KTM', 'LDV', 'LENIT', 'TACC',
       'KANSA', 'FAD', 'AGGRC', 'INFII', 'FLYBT', 'DNF', 'ACC', 'F',
       'REIG', 'BRAVO', 'SINFA', 'CADA', 'GRT D', 'FRE', 'FLL', 'MUS',
       'SATRN', 'IONTE', 'COLEM', 'CHRYE', 'WORTY', 'FE/C', 'PRO',
       'INTIL', 'KAT', 'YYU', 'VESPO', 'UNCB', 'JONW', 'PEN', 'HEIG',
       'MOPED', 'JETTE', 'TJDER', 'MURC', 'NNHR', 'BENSO', 'HAIYI',
       'LARC', 'SATUM', 'AER', 'DUDSM', 'FI/LI', 'FEERR', 'CORBE', 'PETR',
       'UG/NI', 'KID R', 'KENI', 'SPECT', 'DIAHA', 'WBAS', 'PLYUA',
       'HYUYN', 'SETR', 'APRIL', 'MARER', 'TSMR', 'NMA', 'MINO', 'VAN G',
       'SUBI', 'VES', 'BALAN', 'MACH', 'SLF20', 'WFI', 'KENMO', 'HODN',
       'AR', 'GRE/D', 'DAL', 'FRGAT', 'FRETS', 'TEMSA', 'WEST', 'OUTTI',
       'KEWOR', 'SURN', 'HYSTE', 'MVI', 'VAHOO', 'JAMEL', 'LEWIS', 'WOR',
       'GO 4', 'ENCOU', 'HIDAU', 'HND', 'TAR/F', 'LANDO', 'FJ', 'USC',
       'WOLCH', 'DEMI', 'IIZ', '14064', 'MIFL', 'MAIZE', 'MAD', 'YALE',
       'BOX', 'MOTOG', 'MITRU', 'FK', 'WOKHS', 'MILEA', 'YANHO', 'INTRA',
       'MO/V', 'MCLA', 'DIVEL', 'ROAD', 'ACUR', 'PREUO', 'SOLIC', 'DC',
       'KEN/W', 'INTNF', 'MV-1', 'RAYE/', 'KWS', 'L/R', 'WORKS', 'ME/FU',
       'LX', 'FLEE', 'WO HS', 'MAEK', 'ICCOR', 'GULF', 'WW', 'VD',
       'INETR', 'TATU', 'FR/NE', 'MITSK', 'ITR', '03', 'FOSTE', 'LIMO',
       'L/RO', 'ISAZU', 'JUA', 'WORK/', 'BL BI', 'CAILL', 'EAGEL', 'RA/R',
       'CHAPP', 'FKK', 'DELIV', 'TIBRO', 'PLANI', 'WORKP', 'TRAN',
       'HAULM', 'HINIO', 'MONT', 'DIESE', 'ACUDI', 'FGHT', 'LAM B',
       'FUNM', 'TRACT', 'KING', 'CGRYS', 'FREUG', 'FL LR', 'VO/MO',
       'MERE', 'IND', 'SATRU', 'LOND', 'NFIN', 'DELV', 'SPINT', 'IMAN',
       'KURB', 'WO', 'KN', 'PSD', 'HUNDE', 'ATTAN', 'MINT', 'COLLI',
       'MERY', 'GL/U', 'IMCI', 'VOLTS', 'REFE', 'LA/RE', 'BUX', 'JINN',
       'ZIM', 'FEN', 'RGIG', 'NAB', 'SPART', 'GADIL', 'LENOX', 'REA',
       'WES', 'WORKV', 'KAUFF', 'OSHIK', 'CHRGS', 'GLLG', 'HUYU', 'KENOR',
       'M,CI', 'IIS', 'CAL', 'CARIL', 'SATUN', 'PENSK', 'FIER', 'GURDI',
       'TILI', 'FREDG', 'POSCE', 'MAB', 'SYM', 'CADRL', 'AVCO', 'FGL',
       'INTN', 'NAVI', 'THORM', 'HAR D', 'OWL', 'MILLS', 'RN', 'HOSY',
       '67293', 'GE/M', 'GR DA', 'CAN/A', 'KREKH', 'BL BL', 'FRLIN',
       'BUCK', 'COACH', 'DSUZU', 'FBE', 'MAER', 'RERG', 'KENTH', 'WABRA',
       'KAIFM', 'LAN R', 'SICON', 'GEM', 'BK/GY', 'SYSCO', 'KENO',
       'FLINO', 'NF', 'SETNO', 'J=HIN', 'CHTH', 'CADIA', 'MIST', 'JASUE',
       'WOKH', 'SATUH', 'HYUNL', 'MARAR', 'ACARA', 'ME /', 'INTZ', 'MAIO',
       'KUNO', 'RAGER', 'VOLUN', 'HYAUD', 'HNDAI', 'ARREL', 'DVRAS',
       'BERI', 'MIRCO', 'TRF', 'CORBI', 'W/H', 'JA', 'VZ SP', 'VI',
       'GRAY', 'STRG', 'UDENN', 'BATI', 'MARTZ', 'VOIKS', 'LECUS',
       'VANMA', 'UME', 'INFEN', 'CHANG', 'INIF', 'PUCH', 'LARD', 'LNDRO',
       'TK', 'CA/O', 'CAN-A', 'ME', 'PLMYO', 'AUCR', 'AZERA', 'MEDZA',
       '1995I', 'INDIA', 'CADDL', 'STEAT', 'PONIA', 'HAUND', 'TEMSE',
       'W/O C', 'LNDRV', 'APPT', 'SYBAR', 'NEMF', 'IE', 'WOLKS', 'USYZY',
       'CAROG', 'DUC', 'BR', 'INFRE', 'KNWOR', 'MAGEL', 'PIASS', 'ST OU',
       'MZ', 'EREIG', 'TIOG', 'REM', 'MITSE', 'TAOTA', 'RHM', 'HAYUN',
       'VOVL', 'FOST', 'AJAZX', 'VA/P', 'GARGO', '61282', 'WE/ S',
       'OINRB', 'REION', 'LOADR', 'MOTOB', 'TAL', 'STARR', '97TL', 'TNTE',
       'EGLAN', '75', 'GUZZI', 'AMERT', 'WROKH', 'FHT', 'FOD', 'HI',
       'LN/RD', 'GLA', 'TRN', 'WFREI', 'ANNA', 'ACRU', 'FL LI', 'GREI',
       'SUBAI', 'CHDAL', 'ST/AL', 'CHVR', 'FQ/LI', 'UTILO', 'JR', 'WRKHR',
       'VA HO', 'UTITI', 'OLKDS', 'GOS', 'POTIA', 'RZC', 'RIDER', 'SINGM',
       'SEMA', 'TESUA', 'PTRBT', 'UPG', 'OTHER', 'VNTC', 'PROCH', 'INFL',
       'FT LI', 'IZSZU', 'MAXUN', 'WK', 'PROVE', 'N15', 'KRYS', 'MAROU',
       'ORION', 'MALDA', 'WINNA', 'LOA', 'LINKA', 'SLING', 'SEATA', 'L R',
       'TANK', 'ISSUZ', 'MYTY', 'POORS', 'PETEE', 'BR/MA', 'MASES',
       'HA/DO', 'RAID', 'PONTC', 'RANDR', 'YW', 'AUE', 'HYDIA', 'PR',
       'WASAS', 'BONZ', 'WT', 'VLS', 'VANHA', 'MI /F', 'AUCO', 'WARKH',
       'UT LI', 'REIGL', 'WORTM', 'R/ROV', 'SALAN', 'LALRO', 'GWMA',
       'MAXX', 'VWN', 'VESOA', 'COURI', 'FANGA', 'MI/FV', 'CDRU', 'W/HO',
       'HARDW', 'LANDE', 'JAYCO', 'ARMOR', 'JAVE', 'ACCO', 'CARGC', 'MI',
       'GAIIK', 'EORKH', 'FRGTH', 'INFIO', 'FR/MA', 'AURON', 'AIDO',
       'PTR', 'FHR', 'FAST', 'WOLF', 'FAIL', 'CHEYS', 'RUTER', 'KOWA',
       'WO/CB', 'MSI', 'PANTI', 'VOW', 'NILED', 'BUWIC', 'AVEO', 'ORIO',
       'HYUMD', 'ICE', 'HNO', 'WILKE', 'MA', 'COBAD', 'VOLI', 'SAUBR',
       'RAMI', 'PONTY', 'PESTO', 'VOXWA', '7RL', 'GRAT', 'TOTO', 'J AND',
       'IC CO', 'ONCL', 'WON', 'CRIS', 'LA R', 'SEXON', 'TVYI', 'GEW',
       'JMST', 'TANSC', 'SU/BA', 'HARCE', 'TA/TA', 'AUIDI', 'CHYRI',
       'VOLKL', 'TRK', 'DELVI', 'F LIN', 'COBAL', 'ASVE', 'STRE', 'CAYEN',
       'LA RA', 'IIES', 'SCHOO', 'VOLKH', 'POPES', 'LINGY', 'WORKC',
       'FRI D', 'NEWN', 'MARC', 'SB', 'APPX', 'COLUM', 'VENZA', 'PINES',
       'NO/HO', 'EZ LO', 'WIN', 'LUDKI', 'AZUZO', 'FED G', 'WORHH',
       'TRULE', 'BL/BE', 'LO/RI', 'VOLPE', 'HACKI', 'INTC', 'GRIMA',
       'MERN', 'VO/MA', 'FRLK', 'FOUNT', 'KAMSO', 'SATER', 'AAL', 'EASY',
       'AU/H', 'ELLO', 'HMN', 'ROGER', 'TRANI', 'WAS', 'RHINO', 'VA/RO',
       'TALBE', 'FIREI', 'BYD', 'SIENI', 'OLN', 'TINDO', 'LO/RA', 'MARCK',
       'SUBB', 'MG/BG', 'HOMES', 'CADII', 'LINL', 'ALD', 'THUE', 'SAAT',
       'WLKWG', 'RCB', 'FRECH', 'KIDRO', 'S', 'STAK', 'POINT', 'TIR',
       'NZO', 'UKON', 'IDKS', 'HINDO', 'GRUM', 'HAMME', 'SPIN', 'VOLU',
       'RONGE', 'ACCUM', 'BUDDY', 'INFUN', 'UNK', 'STE', 'ESCAD', 'VV',
       'FIRT', 'KKIA', 'DAVID', 'LOODR', 'DIA', 'AUTCO', 'MINI/', 'KC',
       'YAMLT', 'ROUGH', 'KANA', 'HENDE', 'ANKAI', 'FRERG', 'KENWT',
       'AIBJ', 'SITAR', 'DILLY', 'FIAZ', 'ACUA', 'UDZ', 'INEIN', 'HRY',
       'INDA', 'FINT', 'GDAM', 'KY', 'GARDE', 'KEENM', 'LRXUS', 'DAIM',
       'POIN/', 'BRUCK', 'IFN', 'FON', 'RAGRO', 'GROM', 'FSUZU', 'OWV',
       'MOT', 'BARON', 'KEXUS', 'WABB', 'HYNUN', 'HUMEM', 'ISUUZ',
       'MIN=F', 'DENA', 'CNRIN', 'OH', 'ACL', 'LAIRO', 'FRCT', 'RON/R',
       'SPAR', 'LADIL', 'WHO', 'FUSP', 'WASWA', '5FSLY', 'W HOR', 'USBUS',
       'INTF', 'IL BE', 'T-REX', 'LA', 'SHORE', 'ACURH', 'RA RO', 'PBILT',
       'GDAV', 'PEIZA', 'ELDE', 'J J', 'FRE6', 'LA.RO', 'BILTE', 'UNIFI',
       'SOLBC', 'INFT', 'CHYR', 'FREIS', 'HACK', 'FRETH', 'ELD', 'VOLZU',
       'KENLL', 'CHREY', 'SUBRN', 'FRRI', 'FRIZ', 'DUTSU', 'WERH',
       'MEAZA', 'ARG', 'BERN', 'LI/RO', 'CRSLR', 'FRLR', 'SOUTH', 'JAQ',
       'THOR', 'FREIT', '671', 'HYUNI', 'TGOTI', 'NAPA', 'YRAN', 'COTT',
       'KKA', 'COLT', 'MI/FI', 'VK WA', 'GE/MO', 'HYUMN', 'HARDE', 'COMM',
       'MORC', 'BRO', 'HALEY', 'VIS', 'NASSA', 'INTIE', 'VCO', 'RATT',
       'SARTU', 'HUMMS', 'RR/LR', 'ACHRA', 'DUTCH', 'WIORK', 'KENNO',
       'OMR I', 'MECRY', 'CONED', 'SUFAR', 'PIGGI', 'INFIY', 'BN',
       'OUTAN', 'FEDE', 'BUELL', 'SUDN', 'PENN', 'MNL', '3', 'TWF',
       'STARU', 'CHETS', 'STAUG', 'UNION', 'UTITY', 'MELAR', 'TROMP',
       'FRI/L', 'HURI', 'JERRD', 'GRTDA', 'VH', 'LNRO', 'TRJCR', 'WAD',
       'ILTIM', 'PIGG', 'PLAGG', 'FIAGG', 'HA', 'CARTG', 'ME/BL', 'W',
       'HRE', 'HINOD', 'AENWT', 'MKRCC', 'KNEWO', 'SAN', 'MIFU3', 'CIOOP',
       'CM', 'PORTA', 'CEDIL', 'WASA', 'PEJ', 'BV350', 'WORH', 'CHEIR',
       'APPLA', 'ULTIM', 'UES', 'W/OC/', 'VHA', 'LW', 'SULL', 'ME/BB',
       'UESPA', 'CUSO', 'APP', 'FI LI', 'SH LA', 'MTIS', 'PERTE', 'CVEV',
       'HRA', 'VESPE', 'VAHO', 'CASE', 'METM', 'BERSO', 'FR LN', 'RV',
       'ZUZUK', 'M CAD', 'APPE', 'UTMA', 'FALCO', 'JINO', 'RANE', 'KUW',
       'NISSR', 'PRTER', 'TRUM', 'VA/HO', 'FREIN', 'REFG/', 'SCON',
       'HYNG', 'HAN', 'SOLFC', 'CJRUS', 'FREIM', 'WE/BE', 'YL', 'MAE T',
       'SUB A', 'WN', 'TESLI', 'GRTD', 'BB', 'HICK', 'BLK', 'CAYME',
       'GREDN', 'VESR', 'MASEN', 'RAN', 'DEIV', 'NEOW', 'PTRBI', 'VOU W',
       'REFGO', 'UN', 'MCIN', 'TH', 'BENON', 'GTR/H', 'FR LR', 'SATIL',
       'TRAMP', 'GOEL', 'CRAFT', 'MAIN', 'GRN', 'ACUDA', 'IGC', 'LEL',
       'MERRI', 'POYMO', 'HNQ', 'VALAW', 'I C', 'PRE', 'SUM', 'INTEI',
       'UNIDE', 'CEHV', 'FRHR', 'UTICA', 'CALI', 'OLD S', 'BENLE', 'DERA',
       'AM/C', 'PETRA', 'IFIN', 'HYNM', 'K.W.', 'CA/L', 'CHRO', 'SADUR',
       'MVON', 'KLW', 'FR/NR', 'NEM', 'WORKN', 'VESP', 'UMK', 'UMEEL',
       'TRAIE', 'RVIS', 'ZC', 'N. CA', 'LND', 'FR/DI', 'VERUC', 'POUTI',
       'NI/FU', 'MAZ', 'CHESY', 'AVURA', 'VLKN', 'EA/BE', 'BL 30',
       'PALAZ', 'RNRW', 'CANTE', 'LRNW', 'HN', 'JINCL', 'MATI', 'PACEM',
       'KEWNO', 'SMPT', 'GCA', 'TRIPL', 'NESSA', 'WORKT', 'PRV', 'AKZ',
       'PATER', 'WO/WH', 'FREI.', 'HIINO', 'KAITO', 'SATCR', 'ISCZU',
       'FAGE', 'MI FR', 'ZIRSC', 'MT', 'TEX', 'ISZ', 'TRACI', 'LKS',
       'WTHLY', 'MASZ', 'LEXCU', 'MVT', 'BRN', 'LUFKI', 'MACUR', 'TAILA',
       'OK', 'KENTN', 'ZEW', 'UTIMA', 'WO/HR', 'WESTI', 'KURBM', 'AUDLI',
       'WESTS', 'MILFU', 'MBSP', 'PTRD', 'FRT /', 'GRY', 'UTIG', 'GRAMM',
       'SATRT', 'MI/CU', 'FREII', 'IMEX', 'CABO', 'THT', 'FLLR', 'SOLOC',
       'MESRL', 'VOLKO', 'PN', 'VIP', 'HUNI', 'CHI', 'V', 'CONAL', 'HANC',
       'DITMA', 'ONFIN', 'FLC', 'HURLE', 'PRAT', 'HMO', 'SUPR', 'AUTIL',
       'TR/LI', 'HUNID', 'NEON', 'SEMI', 'EIT', 'ASTE', '1Y', 'VIKSW',
       'ST/A', 'MIC', 'POTI', 'SPRLI', 'VO/HO', 'MS', 'WK/HO', 'GSL',
       'MABER', 'HIUNT', 'MESSE', 'LEN', 'WO /C', 'HANLE', 'MORCU',
       'HMND', 'BUDCO', 'CODA', 'MAGUA', 'COL', 'GENZE', 'WH/GN', 'ALLOY',
       'NORRO', 'BUIDE', 'PROV', 'MARCO', 'MAS', 'MIBU', 'INT M', 'KENTI',
       'OLDS', 'CHARY', 'GREAN', 'VIPER', 'NORT', 'VICT', 'CH', 'THM',
       'ITASC', 'APR', 'LO/RD', 'MICED', 'FTIL', 'INEI', 'STEP', 'HONA',
       'INGIN', 'KH', 'CHEN', 'HYLN', 'EADEY', 'ISUGU', 'ISUXZ', 'VOLSC',
       'MUERS', 'NAV', 'SUSZI', 'GINO', 'VOS', 'POWTZ', 'TR/TL', 'NWF',
       'HHUND', 'CABRI', 'N-A', 'MAYB', 'HOMER', 'FREI6', 'HAYNE', 'ONA',
       'GE/C', 'CAMPO', 'MK', 'STALI', 'FGH', 'SUVAR', 'VINO', 'HYUAD',
       'HP', 'STR', 'CAB', 'STEEL', 'W/V', 'IMTNL', 'TAITA', 'WB', 'MFG',
       'SCABO', 'MARCH', 'TOOY', 'RALDN', 'ME VE', 'FIAHT', 'GLGG',
       'UDTRU', 'KAUOR', 'INFI', 'VOLCH', 'LAM', 'MI/FM', 'HINOF',
       'HYLIN', 'FULI', 'KOWFM', 'WC', 'F/R', 'STRUC', 'WASHO', 'WO/CR',
       'BENTZ', 'DUMP', 'KAU', 'ST/Q', 'MARS', 'IFNI', 'HYWD', 'NIDD',
       'KIDWO', 'SUBAD', 'MACD', 'UPS T', 'HDAVV', 'QUEBE', 'YOCHI',
       'KANER', 'HWH', 'CVGC', 'TRT', 'FADF', 'COVER', 'NV', 'CHYTE',
       'MTSA', 'NM2', 'LA/C', 'D', 'SU', 'HYUMM', 'ONTAR', 'IW', 'KAUR',
       'FFREI', 'NS/VO', 'FR/CI', 'ZHNG', 'TAO T', 'FRAIL', 'GREEN',
       'HUYUN', 'HOMET', 'BLUET', 'AY', 'ET', 'WAEAS', 'UHL', 'SBUL',
       'DUI', 'TURNB', 'KENTO', 'VN', 'PETRB', 'LINE', 'BROWN', 'AREMO',
       'HRS', 'MOZOT', 'LEXU', 'CONRI', 'VST', 'INC', 'REFRI', 'HYUNC',
       'UHK', 'ULITI', 'KA', 'SRPIN', 'MOE', 'IC BU', 'B/BI', 'DODGB',
       'KURMA', 'GRAET', 'TCTR', 'SAMRT', 'FARLE', 'LTULT', 'HIRO',
       'CHEUR', 'VLO', 'FUZO', 'FN', 'SAMR', 'GRYMM', 'WROCH', 'RANT',
       'SUBIN', 'DFREI', 'DECU', 'CMA', 'AIRST', 'HYBW', 'BURG', 'SUYZU',
       'WORKG', 'RAIFU', 'ACURN', 'BILBI', 'YD', 'ZENTI', 'HAULE', 'FY',
       'BIBI', 'CHYST', 'WOLK', 'METBE', 'J&J', 'IAFIN', 'GAE', 'KENKO',
       'KM', 'PJ', 'GDE', 'KANOW', 'KAMCO', 'FLOOR', 'LARVR', 'CHRES',
       'HYOUN', 'FR LT', 'SABAU', 'WOLVO', 'MIMI', 'MITS/', 'TEMPS',
       'NINO', 'SCARA', 'WRKVA', 'GSCR', 'MI/RY', 'BFMS', 'PARBE', 'MASD',
       'SUZUB', 'QS', 'IT', 'BI/BI', 'WALSH', 'LEXCS', 'VAH', 'FRT D',
       'PETOT', 'CHRYP', 'KGW', 'K', 'LO/R', 'CRAGA', 'WOHO', 'FLHT',
       'IESU', 'VOKW', 'FH', 'FRE T', 'VESPC', '`APRI', 'FR/T', 'LIML',
       'TULSA', 'PRESV', '4VDI', 'BV500', 'FIGHT', 'FT', 'LO RO', 'X',
       'TVR', 'BLU B', 'TESCI', 'VULCA', 'PETRE', 'VIRGM', 'STOLI', 'MIT',
       'MCY', 'UR', 'VNHO', 'CLARK', 'KI MO', 'DENNI', 'SUARU', 'SUD',
       'INERN', 'COURT', 'MOBIL', 'TRAIK', 'PRIMP', 'RA', 'CFHG', 'JUP',
       'UYILI', 'CADIT', 'CONV', 'MCU', 'FREY', 'DUKAD', 'Z2LMR', 'PONI',
       'MALK', 'TRACH', 'MURCE', 'ININI', 'MAUK', 'ESEAU', 'YAHOL',
       'INFTI', 'I/C', 'ORD', 'KIAWA', 'MRV', 'CEBRI', 'THO', 'CADOL',
       'HI/FU', 'CHEST', 'GDN', 'VESPY', 'HYMME', 'XCITI', 'XL', 'CVHRY',
       'NASER', 'UHAU', 'FEDER', 'FR/LR', 'SIENA', 'FREYL', 'PTBLT',
       'WCSTR', '.CHRY', 'SPON', 'STIRL', '01AUD', 'A/C', 'INT V',
       'CERGO', 'FED E', 'PLAT', 'TRITE', 'INCOL', 'M2R', 'IVS/O',
       'FREIR', 'UNTIL', 'TI- B', 'GED', 'HAKN', 'INT N', 'POTSC',
       'CADIW', 'REG T', 'CRUSL', 'MIFO', 'INERB', 'HIMO', 'MITMI',
       'LND/R', 'DELVT', 'SURA', 'MH', 'ISEZE', ';EXIS', 'HOMEM', 'ZHING',
       'WE/ST', 'FREE', 'STKJ', 'KON', 'PHAGG', 'NE/F', 'IZ', 'FREZG',
       'SEDAN', 'EQUIN', 'AZ', 'INTEV', 'WO H', 'FRLN3', 'WETER', 'LONGU',
       'INTOI', 'RGU', 'CHIN', 'BUIC', 'DODH', 'STELI', 'HYDAN', 'MUST',
       'GRIF', 'KWSKI', 'TLK', 'HDVO', 'TMAX', 'INL', 'HAYDA', 'I',
       '2012', 'EASTN', 'CADEL', 'FE180', 'UTLI', 'TRAO', 'ISUIZ',
       'WINNI', 'KOM', 'STERH', 'VOLVL', 'FILN', 'TEISA', 'C ADI',
       'FN/LI', 'PARS', 'GUSO', 'THIN', '2', 'XPO L', 'KWO', 'VOLKK',
       'FRIDG', 'UB', 'WINNS', 'FIBER', 'FALZ', 'TE', 'RERGE', 'KENDW',
       'MG BG', 'GDT', 'HINO3', 'RNG R', 'MU/FU', 'ACVRA', 'FLING',
       'LEUX', 'HUNAD', 'VEPSA', 'CALIF', 'MACU', 'CHA', 'HANDI', 'HYUNE',
       'BLLUE', 'VACO', 'ZEN H', 'FERO', 'VK', 'INTIF', 'OUT', 'JIND',
       'EVERG', 'BEACO', 'LAFIN', 'FRTLN', 'POSDN', 'GOBRA', 'POFS',
       'REVGE', 'VPOLK', 'GEN', 'SUTUR', 'SRICK', 'KARAV', 'IFNIN', 'CNP',
       'DHL', 'MIN C', 'FREH', 'CHURY', 'ASMA', 'GCR', 'SINBA', 'HYU N',
       'TOURI', 'RD', 'WAGS', 'VANHS', 'GRISM', 'ACION', 'PREVS', 'VAMHO',
       'BRICK', 'STRAC', 'CHASI', 'FRG V', 'REIGH', 'MITSC', 'MM',
       'SCIEN', 'MANL', 'LANRV', 'HIA', 'ELEGA', 'W/S', 'DRIEN', 'EASR',
       'GIL', 'OC', 'HUYAN', 'TRACK', 'ROKET', 'MAGER', 'MSA', 'GRATD',
       'PIAGI', 'SBB', 'GARY', 'TRUC', 'HRI', 'CHAT', 'PULSO', 'HELL',
       'CRYSH', 'MERLY', 'AUTI', 'MACKD', 'MG/BE', 'SUBUS', 'VACK',
       '2013', 'TRALE', 'XYAME', 'MI/RU', 'STANA', 'FERU', 'FORTU',
       'UTI L', 'MASTA', 'UNI', 'RAUSE', 'DELVA', 'FRIEH', 'MO/LE',
       'VOLV', 'LH/KO', 'HOCKN', 'MO G', 'IRP', 'CPR', 'WIL', 'HNI',
       'H/WH', 'WKRVA', 'TRE', 'UD/NI', 'MSE', 'TU/T', 'CADAI', 'VW VO',
       'PR BI', 'FLAIR', 'XEN', 'DULAT', 'W/O', 'SEALI', '05', 'RNBMI',
       'SCTON', 'BINTE', 'ASMAP', 'VIW', 'GV', 'ITAS', 'MRESU', 'FRE L',
       'MECRU', 'INTRL', 'GULES', 'ELDR', 'UITLI', 'GR. D', 'G/D',
       'FREIB', 'M TCK', 'POSSC', 'HI/FO', 'ULTIY', 'SUG', 'ICWRP',
       'HA BA', 'WHN', 'INFIB', 'FETE', 'MERRC', 'NHLI', 'MICV', 'FT CR',
       'DTTL', 'MINA', 'ESCAR', 'ITNER', 'FRIEI', 'CANAM', 'KCATW', 'SUI',
       'SNART', 'ASTRE', 'TRTE', 'L', 'CLMNT', 'JJEEP', 'CHRYQ', 'ISUXU',
       'GDW', 'LEXAS', 'FLUND', 'CRYSI', 'OAURA', 'OLMO', 'TCK', 'WLKS',
       'EMC', 'PREGO', 'COA', 'WORW', 'BAZ', 'PONRS', 'UWGOL', 'FRENI',
       'CHUNF', 'PEFER', 'OLDSH', 'HYON', 'ARAM', 'MRCU', 'ELKH', 'MADI',
       'SUNBA', 'UALU', 'HYLUN', 'CRAN', 'Q', 'VS', 'JJ', 'MICHI',
       'ECONL', 'OSUBA', 'TRAVI', 'WERIS', 'CAPIT', 'TLX', 'SCLON',
       'WOLLT', 'ING', 'IOL', 'SBR', 'TAUOY', 'BLU', 'POWER', 'JOHND',
       'TI-BR', 'YU', 'HYAUN', 'HYADA', 'CAMP', 'PORSG', 'HONRA', 'BON T',
       'PETE/', 'KAPMA', 'SABR', 'ORLON', 'GWE', 'BREIG', 'CAB C',
       'CLYSL', 'PEPSI', 'LADRO', 'WI', 'RANGU', 'SANAT', 'ISURU',
       'PURDE', 'VIKIN', 'FERD', 'TEMP', 'VENTU', 'LIEBH', 'MCARC',
       'PRAGG', 'BOXFE', 'UIT', 'PLYMM', 'BEZUT', 'FZ/LI', 'EAMC',
       'KEWNW', 'MITFU', 'SHAD', 'BOULE', 'HYW', 'PT CR', 'MCR', 'TROG',
       'UW', 'FAR', 'PATH', 'FE/LI', 'ZE', 'RIER', 'FRUE', 'IS', 'SYZYJ',
       'MINI.', 'MB/BE', 'UTLY', 'MHS', 'DUBAR', 'FLIN', 'VG', 'MAETR',
       'PORSD', 'BELIC', 'MORNN', 'PORIS', 'ELA', 'MIFUS', 'ASAX',
       'EAST/', 'CAMMI', 'BESPA', 'POG', 'CADIZ', 'ISF', 'VESSA', 'NELS',
       'SLEV', 'WORHO', 'GOVER', 'PER', 'ME/DE', 'TAV', 'KOKON', '7ECM',
       'GRUMO', 'MACK`', 'NEWRA', 'CARG', 'WHISP', 'AZURA', 'ZNOTT',
       'ACUM', 'OMFI', 'TAILG', 'STAIC', 'FRHTC', 'M ACK', 'SOTED',
       'NAUL', 'OMODC', 'MET', 'TOYOL', 'HAUN', 'CAMR', 'NPR', 'HUDAY',
       'JLG', 'HAVOC', 'PORTE', 'HIO', 'KLENW', 'PIAGS', 'DUN', 'UP',
       'MAXIN', 'UTER', 'UHUAL', 'INO', 'CHYSI', 'VLSW', 'MITZS', '95',
       'PREVE', 'SIBAR', 'LORO', 'MASA', 'TREI', 'MADA', 'UH', 'KIN',
       'ROSEB', 'DUCA', 'MI/SU', 'VANHD', 'KEM', 'DA1', 'BRKH', 'EIA',
       'KIA3', 'DURA', 'GREND', 'OFMAT', 'MERCW', 'AU', 'RANDO', 'PEOPL',
       'VOLW', 'MAERR', 'KENNI', 'MICKY', 'DCLI', 'CO', 'LODC', 'SACH',
       'B2ZUI', 'FRIGT', 'SATON', 'THERL', 'MTI', 'THEMO', 'NIIS',
       'MI-FU', 'WD', 'YR', 'JMARY', 'ULTR', 'UTL V', 'SMARK', 'CHALS',
       'TESLR', 'ZSUZU', 'VOLLY', 'TES', 'BECLI', 'YAMAC', 'MI BE', 'AN',
       'ME/BI', 'OKL', 'TESK', 'VA HI', 'FLEI', 'POLY', 'ERUEH', 'BUBAR',
       'ZEN', 'WRKTB', '67447', 'INRTE', 'HW', 'YAHM', 'BE/B', 'JOURN',
       'BEN', 'SMLU', 'FRANK', 'IZUNU', 'GIRA', 'CORAN', 'PRT', 'OACRA',
       'POLAR', 'AURO', 'SPEUA', 'RPB', 'V2 SP', 'VIRO', 'SZION', 'NISSO',
       'WORKF', 'WFL', 'YIBEN', 'VHEV', 'FR -L', '4YU', 'FRB G', 'ARCUA',
       'HARWA', 'TYHLD', 'SYMG', 'ACIRA', '02', 'WEKH', 'FRC', 'KWD',
       'MIED', 'HYIND', 'SION', 'FRGPT', 'OLOS', 'WUSTO', 'PROST',
       'VAL W', 'UNO', 'HOURA', 'MCI6', 'FE', 'OLDMB', 'MI FL', 'GALL',
       'SONAF', 'MASRA', 'FONTI', 'HION', 'HYMAR', 'HAND', 'BL /', 'OWD',
       'LAYMA', 'PRU', 'SUZCK', 'FART', 'LN RO', 'JUAGA', 'CONTA', 'MHSU',
       'HERK', 'CABCA', 'FR/WT', 'UITIL', 'FORSC', 'BMW0', 'FURD',
       'WO/CO', 'METCL', 'WKH.', 'MFIIC', 'SWM', 'VANHL', 'VSIA', 'FRATE',
       'UTIIL', 'FRHGT', 'B,W', 'URAL', ',MACK', 'CATOR', 'KIL', 'CAI',
       '15218', 'COVEC', 'TLG', 'SCLOA', 'VANHU', 'NFINI', 'INT L',
       'MINTC', 'VULLA', 'LI', 'MI/F4', 'DOPGE', 'INTHU', 'SY=UZ',
       'SEABO', 'R-ROV', 'REIGI', 'ARGO', '07', 'DAN', 'WESTW', 'FOREL',
       'HYNO', 'SPREE', 'QLWK', 'WALAS', 'ICA', 'ADDUS', 'LEXCO', 'VOLKJ',
       'PLUMO', 'KANDR', 'MASLA', 'PONSC', 'AII', 'A', 'ANC', 'LE/RO',
       'TR/VA', 'NHNIT', 'OMS', 'URP', 'WO KS', 'GA', 'CMAYS', 'MAZOL',
       'UTRY', 'BUICH', 'SUNSP', 'KAUAS', 'KN KW', 'RAY', 'AURA', 'CONNE',
       'KIV', 'POSER', 'GAET', 'JAGUU', 'HAWKE', 'MO/OL', 'HONBI',
       'RORVR', 'METS', 'POT', 'PRSCY', 'OOCL', 'MT/FG', 'TESBN', 'V OLV',
       'POWTI', 'LAMB', 'FREN', 'HINOU', 'FT/LT', 'VOISW', ']FREI',
       'FRHTL', 'VCOLV', 'INTIO', 'DACAT', 'GENEE', 'URIL', 'FRYK', 'MLT',
       'LUTTE', 'NERA', 'RAIN', 'NORCH', 'VWGN', 'PIUGG', 'LD', 'USP',
       'CHSLE', 'SHENZ', 'STAIL', 'UAB', 'VANO', 'THEO', 'IAN', 'MINIE',
       'CCHRY', 'KU', 'HFIN', 'GRANT', 'TYRIN', 'PORSL', 'REBEN', 'GLLI',
       'MISRA', 'LANR', 'ATC I', 'INTY', 'SAAUB', 'MHN', 'FHRT', 'CARGS',
       'CENTE', 'R.ROV', 'EMFIE', 'AJAY', 'SEAFR', 'MASOR', 'LOGAN',
       'PETYE', 'FZEJ', 'M/VE', 'RAGE', 'MASSR', 'FARB', 'WOC', 'VOKLK',
       'VOIX', 'STERA', 'PANGI', '112', 'QUT', 'SLIG', 'APEX', 'UTL',
       'WRK/H', 'HWY', 'CAMER', 'KENC', 'KI/MO', 'LAROV', 'FB/LI',
       'SINGA', 'RENO', 'FUS', 'KWOOD', 'PAMPL', 'SUPRE', 'PORJC',
       'ST/AC', 'VAN/H', 'LANOL', 'FGHTL', 'WRKG', 'BOXTR', 'BL/RI',
       'D FRE', 'N13', 'ICE C', 'GVW', 'HIDO', 'INTO', 'SAUZU', 'WOL',
       'JI', 'GU/S', 'HOMME', 'RENWO', 'REMUR', 'TRUTH', 'MICR', 'PRIU',
       'MESUR', 'SUNL', 'AURI', 'SEACO', 'BA', 'UTRL', 'NASS', 'HINL',
       'MOLG', 'FABRI', '.INFI', 'VERDI', 'PERI', 'VL', 'FLAN', 'FINDG',
       'JUIMD', 'CACDI', 'YAND', 'PCMP', 'FR  L', 'USPS', 'XM', 'FTLNR',
       'DMC', '2016', 'BRIMA', 'TRY', 'BRWN', 'ACME', 'WORTK', 'PERIG',
       'UIL', 'HYLAN', 'HAODA', 'HDYI', 'AUDIU', 'MACR', 'NEWBL', 'CHB',
       'TIMEW', 'SKI', 'SETTR', 'ITILI', 'PORIT', 'APPOX', 'ZNTYR',
       'STERC', 'ME/RE', 'PI', 'NFEIN', 'MOOK', 'MERG', 'NKN', 'VOXW',
       'CHPRY', 'UPS W', 'ZENN', 'KENWS', 'SAMEH', 'FIGDE', 'FR/LL',
       'GRAL', 'FALT', 'UPS F', 'HYNDY', 'VANSE', 'BECK', 'CAR', 'MAZEN',
       'ONCBC', 'MEDCE', 'KENWU', 'BLUEH', 'UTUS', 'COVIE', 'APCHE',
       'AUBAR', 'TOWTR', 'AYDU', 'HYUIN', 'SUZS', 'ELK', 'HHINO', 'BLANC',
       'METZ', 'PORON', 'NUFIN', 'HAWTH', 'UTILU', 'CRISL', ';EXUS',
       'ARCUR', 'UTUTY', 'NWCLM', 'MBRCU', 'FREJ', 'VM', 'OTUS', 'WAN',
       'FLOY', 'MISTA', 'CADIH', 'HUMDA', 'SULAR', 'PLYO', 'JETT',
       'CESCA', 'EXUS', 'BENEL', 'MARYL', 'GLINE', 'BROW', 'PHEO',
       'PACIF', 'D DAN', 'TER', 'FGREI', 'LA/OR', 'UTIM', 'IU', 'CAD.',
       'LTNK', 'VANT', 'LEDUS', 'LEUXS', 'RETUB', 'HOVEL', 'MSTCK',
       'KIDOO', 'SEBAR', 'ALARO', 'INTL', 'ALDE', 'UBTER', 'RAN R',
       'QIANJ', 'INTLR', 'UTERK', 'DELNE', 'CCADI', 'TELS', 'JNG',
       'QUICK', 'AS MA', 'YURKO', 'CDAIL', 'BCL', 'TRINN', 'VK WG',
       'VOCKR', 'COZY', 'SERTA', 'UIS', 'FRIED', 'PONCE', 'FLIDE', 'WELL',
       'ICRP', 'LOX', 'JAGUG', 'TRGHT', 'PROSH', 'HIU', 'DUCAY', 'VLKWS',
       'VOTVO', 'GUST', 'EDSE', 'DUKH', 'SPR', 'SATUA', 'ALMUR', 'MOUIT',
       'LARND', 'VANWH', 'LENW', 'LEWXU', 'BASHA', 'GR/OL', 'DEM', 'RAM.',
       'WOK', 'UBFUB', 'AID M', 'LAREO', 'LENWO', 'LUXES', 'YOI', 'UCBC',
       'FR HT', 'IY', 'UPSTR', 'ETON', 'PANT', 'SUDAN', 'FRVAN', 'FRAIG',
       'ZPLAT', 'JEGLA', 'HINY', 'HYYUN', 'FIART', 'BENO', 'FRER', 'KYMC',
       'G DAE', 'SCHRY', 'BLUO', 'OHI', 'INFNT', 'HYUNK', 'WKHO', 'GATOR',
       'VYAN', 'REFER', 'ACBUR', 'HORL', 'POIND', 'MERC', 'FO/R', 'DAI',
       'M/TR', 'AMHR', 'FREIF', 'TRI S', 'VLSP', 'LT/RD', 'EXVS', 'NASSI',
       'FL70', 'OLDMA', 'N/V', 'WORHK', 'SUBIA', 'RFOVA', 'ZANOT', 'INP',
       'CAIEG', 'TN', 'TUSTI', 'EVEER', 'KIURO', 'BRI-M', 'HYAN', 'PONGA',
       'MU', 'SOKL', 'SOLER', 'FIHL', '2RU', 'PORES', 'HING', 'HOWD',
       'MA/DA', 'FONRA', 'JAGQ', 'HID', 'RW', 'TUSCA', 'EOUJH', 'CHEVI',
       'CONDO', 'MIDCA', 'OHIO', 'PLAG', 'BMS', 'FTLN', 'AUUDI', 'OJYC',
       'OETER', 'KINZO', 'DINEO', 'KARVA', 'L ROV', 'HYUBA', 'EZ-CO',
       'OSIZI', 'NASAR', 'STUN', 'FLR', 'COMLU', 'HUNY', 'GENII', 'HYUN1',
       'FORE', '15424', 'CYSLE', 'BU', 'GESC', 'SATEN', 'PERE', 'OCBRY',
       'LEXQ', 'WORKR', 'ASIMA', 'GANE', 'WCO', 'LNFIN', 'URENT', 'CHEVG',
       'MICKO', 'BI BI', 'SCIOR', 'FN/LN', 'KW TR', 'GREA', 'MIMO',
       'FREIE', 'KEUWO', 'LEXOS', 'ACAD', 'VDLV', 'PONDI', 'ESC', 'HRLY',
       'OYTO', 'CHRY+', 'ISSUE', 'RANIR', 'CUSHM', 'UDTEN', 'UPS/I',
       'TIOGA', 'VOLBR', 'VANWO', 'QS2', 'MECOX', 'GY', 'DURAS', 'MACY',
       'FRTTR', 'SUL', 'AUDII', 'VALAG', 'KINCO', 'CA7', 'BITE', 'FENW',
       'NFW', 'ATLAN', 'SMAT', 'RWO', 'MOUTA', 'BENTI', 'SUGAR', 'STUR',
       'VOLKE', 'YADIL', 'FRENA', 'HINU', 'RANG', 'ZONGS', 'FEIG', 'FR/U',
       'RAN/R', 'ZUMAN', 'FRGS', 'ORYSL', 'MECUA', 'KEMWO', 'PTRBL',
       'HINK', 'LO/RZ', 'THOME', 'TR/TE', 'HYUMI', 'EXIS', 'WIM', 'LEC',
       'WA/HO', 'TIOGU', 'GOLDE', 'CARLA', 'ALLEG', 'ICBUS', 'WEB', 'VQ',
       'VOK', 'AUDEI', 'HFREI', 'THOUA', 'TCBS', 'EMPIR', 'KLIA', 'MIAMI',
       'MAINE', 'EZ/L', 'ME/AR', 'UTIS', 'CIA', 'OMTI', 'TRB', 'CABLE',
       'CATHL', 'NYUND', 'RETER', 'HO', 'VJOLK', 'MTRL', 'VILLY', 'FRESH',
       'REFLE', 'DOON', 'ELLR', 'MASUR', 'HS', 'FREKH', 'INREI', 'MEREU',
       'EC', 'KISA', 'COLOR', 'SETZ', 'BENDI', 'LA/RR', 'FN/LT', 'CADUK',
       'FRGLI', 'JT', 'MIKEY', 'HINDD', 'FYL', 'HERCO', 'TGB', 'SM',
       'VOLZA', 'WOR/H', 'REXH', 'LNO/R', 'HIWH', 'LINO', 'GRU', 'ACERS',
       'VSP', 'GILLS', 'ACU', 'JAGG', 'LINLC', 'VKWGO', 'MEREE', 'WORKA',
       'APN', 'BL FI', 'FL/LZ', 'SUKI', 'B4BI', 'SMARI', 'PIEAG', 'YUCKS',
       'FREUC', 'WAN C', 'GREMT', 'LAFLA', 'WIC', 'DOGE', 'WERHH',
       'TOW C', 'KJM', 'IOW', 'CLUBC', 'MI/FO', 'VOLJS', 'ST AL', 'VOLWO',
       'PONT', 'CHEY', 'VOLK-', 'LAFKI', 'DOWNT', 'CODIL', 'REITN',
       'VOLTZ', 'MACGA', 'UTLIN', 'SUMBA', 'PUNTI', 'VENOR', 'RORXR',
       'VIOLK', 'NL', 'CHNO', 'SZUKI', 'NH', 'FNC', 'LEXIU', 'IC CE',
       'VKW', 'WRKMA', 'DUREN', 'H S', 'MIT/F', 'KENWI', 'CDL', 'ZUSUK',
       'SHRVS', 'BRTO', 'DJFIN', 'AEROM', 'FTWD', 'MIDAS', 'DUNBA', 'NT',
       'DAYON', 'PRUIS', 'DROVE', 'FRAIT', 'THUNG', 'ZUTER', 'UEBH',
       'KIMO', 'ASLMA', 'FRIGE', 'MWI', 'TRATE', 'LAE', 'IONH', 'MASIR',
       'V/W', 'ODAI', 'CA ON', 'FREIV', 'VO/NO', 'HUZ', 'YOLKS', 'NOLLE',
       'KEMUB', 'DORCE', 'JAGNA', 'LEXIN', 'STEAR', 'MIRSU', 'HYOVN',
       'HR/DA', 'ALMRA', 'W/VAN', 'MASR', 'FRGIT', 'VOLT', 'NFIH', 'CHSL',
       'MARLE', 'MI /B', 'SOLSC', '13', 'MO/O', 'VN7', 'LLEX', 'CHYLE',
       'WOHP', 'TOURE', 'PREIS', 'YAWA', 'ST', 'PLEYO', 'SUZWK', 'HURDY',
       'VOLTW', 'CTASC', 'PIACC', 'PEERB', 'ALEXD', 'FEDGI', 'HYUDD',
       'HUYDA', 'R/NO', 'FRY', 'INPIN', 'NTER', 'CARY', 'FRTR', 'FREVE',
       'TMIX', 'BASTO', 'GRTDR', 'WH HO', '2E', 'HNDY', 'WWAGO', 'VERA',
       'YMSID', 'LEM', 'AMEHY', 'MCZDA', 'DAIX', 'G', 'SMT', 'MW',
       'ABARI', 'PORGC', 'KNWOO', 'FASSA', 'FRZ', 'DIREC', 'SOBC', 'GENE',
       'EX', 'ISSUU', 'TRAM', 'CHVE', 'CHHRY', 'POETI', 'FTLC', 'DENNO',
       '250IE', 'DUACA', 'KEWWT', 'BRIGH', 'MUNN', 'SMAN', 'RIAL',
       'MT/SU', 'SALEE', 'V0LKS', 'CLMT-', 'OMC', 'SNBOO', 'CASCA',
       'MI/PU', 'ENOVY', 'MDC', 'JSIEO', 'MEC/B', 'JARUA', 'SAGUA', 'IES',
       'TOW M', 'INTAR', 'WPI', 'TRNSP', 'CRAE', 'SURU', 'MI/IN', 'BREMB',
       'CHRST', 'UTTP', 'SUMER', 'HOLI', 'U HAU', 'WO0RK', 'ISW', 'INTFL',
       'FONT', 'ESCLA', 'GRC', 'UITL', 'HYUNP', 'INTCE', 'CANDI', 'HERUC',
       'FL/LI', 'SCIAR', '67592', 'KUZU', 'VRKH', 'WABSH', 'DOR', 'SATLR',
       'VOLTE', 'FIRE', 'HUT', 'PERV', 'JANWA', 'BUIK', 'WG', 'TIME',
       'GYUND', 'CRD', 'FRUH', 'RA/T', 'IZUZI', 'CHSRY', 'LR3', 'HUNAI',
       'WTL', 'LEKUS', 'CAILD', 'MURCY', 'LA LR', 'PORCI', 'VLKWG',
       'CAR2G', 'PENEL', 'INT T', 'VANHH', 'BODGE', 'WK HO', 'SUR',
       'LEXIC', 'PVN', 'COURN', 'IDLL', 'ASI', 'GND', 'HUGHE', 'IAKSU',
       '67600', 'COLOM', 'COONO', 'GREM', 'MELTH', 'JJAGU', 'MITRC',
       'MAZZA', 'BOZCR', 'CORUE', 'FE LI', 'INTE', 'FRJ', 'KEMUA',
       'V. HO', 'MAR', '0410', 'DOWN', 'JLGIN', 'BI/BL', 'SCOOT', 'SUTTE',
       'GEO P', 'NHHI', 'RA/RP', 'INFTL', 'LKENO', 'VESSP', 'ZENI',
       'FRELC', 'MECER', 'GR LI', 'MN', 'BV 35', 'MUTS', 'GEO/P', 'BRSC',
       'PT BL', 'ALTUM', 'RAND', 'SIGNT', 'FUSU', 'G=FRE', 'CHRLS',
       'STARN', 'ME/B', 'OLDST', 'POURS', 'BNTIA', 'CYRSL', 'PRESE',
       'MECE', 'MCIA', 'MASCR', 'FTRB', 'PTR-B', 'MUK', ',FREI', 'ACUI',
       'VINTA', 'HYUBD', 'F/INE', 'WH/HR', 'AWCA', 'MCD', 'CLEME',
       'LA/RC', 'LU', 'MOTIV', 'FT/,L', 'KENAT', 'WHILE', 'MALL', 'CUTA',
       'FORTA', 'BEHZ', 'INLER', 'TESMA', 'PORGE', 'MERAC', 'ARM', 'VEPA',
       'GRUNA', 'HMD', 'WORLK', 'ANKAR', 'SEB', 'WA/RO', 'BU/B', 'FIELD',
       'FR9', 'LRAO', 'WTI', 'DEAN', 'AUSTO', 'FZAT', '7UDI', 'JOYCO',
       'RA/RD', 'MGI', 'ROGE', 'CARL', 'JONWA', 'MI/EU', 'CRUIS', 'SPRUN',
       'RHING', 'MARON', 'MACPL', 'FR/LG', 'HUDY', 'LEXYS', 'CUSHA',
       'INNFO', 'SOUEC', 'BR/M', '1996', 'WOKRH', 'FRILI', 'VAN T',
       'CON E', 'UMR', 'SZUBH', 'DADI', 'AL/DE', 'HYUN.', 'SOBEA',
       'LKEXU', 'JW', 'W/O/C', 'MENE', 'HYOS', 'GC', 'NISSX', 'KENMD',
       'JAMBO', 'BL/I', 'DT466', 'MVF', 'HYTN', 'W H', 'AJAK', 'CARCO',
       'TPYO', 'FUDI', 'HUL', 'WELLS', 'YAZNA', 'ZKMT', 'PT', 'KRYST',
       'KERIL', 'DERBI', 'MNERC', 'CO/TR', 'HINAR', 'CAND', 'QORKH',
       'EL DO', 'LY', 'BLBL', 'LAYRO', 'RAIM', 'RANSE', 'ABCO', 'TRACC',
       'PENER', 'VANS', 'HC', 'MASTI', 'RUV', 'KWOO', 'HRHS', 'H D',
       'ALLE', 'MECO', 'MD', 'HOOL', 'CADI-', 'VINGS', 'TREX', 'HIUS',
       'QINGD', 'WHT', 'LJR', 'DLIV', 'CUMMI', 'TRAVC', 'KEASW', 'OVW',
       'KANM', 'PENTI', 'RONRU', 'BRUIC', 'PL', 'RUR', 'IMAZD', 'RIMCO',
       'PYMO', 'VST/P', 'HUNDU', 'ROCKF', 'SOLEO', 'DAIHA', 'POESC',
       'CNEV', 'CALKI', 'W/W', 'VOIVO', 'ENCO', 'SMN', 'MIFY', 'SUBAK',
       'FLORE', 'HA/RO', 'GYON', 'MIM', 'VW JE', 'CTIRS', 'SCALA',
       'GRANE', 'POATA', 'BRW', 'HANSO', 'KAWO', 'MTER', 'PESTE', 'MAZA',
       'FR LY', 'FRTLM', 'RADL', 'AUDUI', 'KEUFM', 'SURBA', 'HEURA',
       'V/N', 'ENDLI', 'LESLA', 'SAGUP', 'SPRT', 'FR-IN', 'KENTA',
       'CARGE', 'UTI M', 'TESIC', 'GIVI', 'CIMS', 'HONE', 'GIMC', 'GR-DN',
       'BK', 'BAM R', 'SUZIC', 'CHRV', 'DUMBE', 'KEMO', 'FINTI', 'HURNV',
       'DENNY', 'US', 'INLO', 'INNFI', 'UV', 'SUCAK', 'KYUCO', 'SPRNT',
       'EAST3', 'FLY', 'GUMAN', 'MAC', 'SCIRA', 'OLLSM', 'PTEB', 'RO LA',
       'SOLET', 'MARDC', 'FORLE', 'AJAZ', 'RO/LO', 'VOLER', 'GRUAN',
       'VOLKU', 'MCIKE', 'OLIVE', 'GENIU', 'SAV', 'ECHAM', 'SO/W', 'KUSH',
       'UT.L', 'SOLCE', 'SCBER', 'G DAV', 'BEIG', 'INT H', 'PUFZU',
       'KIMMO', 'VOKLS', 'CIACO', 'BOREE', 'TODCO', 'ACOOC', 'MOSER',
       'PR-PU', 'CHRYY', 'SOLZA', 'UKHS', 'CUTAW', 'TITTA', 'MKH',
       'FRUGH', 'MIDLA', 'E', '3MPNZ', 'SOLEL', 'MACA', 'TRICK', 'M/C S',
       'FUSE', 'BOUR', 'MI /', 'PIAJ', 'FAL', 'ISUZ', 'NIGHT', 'AUNDA',
       'FEIGT', 'ROLLI', 'KENLW', 'UNHC', 'HYUNN', 'COUVI', 'BURND',
       'C/MC', 'SAMEN', 'E7Z', 'NSSN', 'POLAL', 'FREGY', 'WERNE', 'RAICH',
       'CAUAM', 'TRIR', 'MICLE', 'ORIV', 'HINOP', 'F L', 'MGM', '7C',
       'XTASE', 'INVIH', 'ME  B', 'CLDR', 'XTASC', 'HARTG', 'SERL',
       'UNIUE', 'CD', 'IENUM', 'STALC', 'PLMOU', 'ININF', 'ELEZT',
       'DORCH', 'SPRIS', 'STEVI', 'ITYUN', 'VOLK,', 'IERN', 'KINGS',
       'MALAY', 'CRDOL', 'SR[NT', 'SWVO', 'RAM H', 'INIFN', 'BAYB',
       'MEIAU', 'KASAW', 'FIAX', 'SBURN', 'VLG', 'VANPO', 'INFZ', 'PEENY',
       'FFTE', 'HERUL', 'CLEVE', 'WE/C', 'TROUM', 'FRIGI', 'VXW', 'RI/FR',
       'DUCAI', 'LAN/R', 'EAE', 'GEMIS', 'LA/RP', 'TRINT', 'SUABA',
       'KENWD', 'FREDE', 'TALTA', 'AMT', 'DCLT', 'HYU8N', 'BARCH',
       'RANLE', 'VTILI', 'HAMAM', 'WILLI', 'TOWNH', 'ACUST', 'THINW',
       'MARDA', 'FRN', 'MURER', 'KUAN', 'SE', 'MOTER', 'VIN', 'KEUNO',
       'TRATI', '2RAR', 'KAUFH', 'SONOT', 'PONTZ', 'JT/MA', 'KAMWA',
       'SUARO', 'WHRNO', 'KQ', 'WHI F', 'WHCU', 'ROCLE', 'SMAER', 'LIL R',
       'UTILA', 'CATI', 'NAUIS', 'HYRD', 'KENRD', 'RAM', 'AUDR', 'ZEMT',
       'DUNAT', 'LEXUI', 'BURCK', 'RAMM', 'UTIY', 'HENW', 'MAAI', 'MEKC',
       'TINO', 'HINDI', '9NITI', 'PAM', 'MI/FY', 'WOTER', 'CIBA', 'FR /L',
       'SKY', 'NORTH', 'HYNI', 'HYOSU', 'TORVE', 'WLK', 'XRYSL', 'MAGNA',
       'CHADE', 'MATSU', 'STANG', 'FIAI', 'BART', 'FR/LU', 'HYD E', 'MAK',
       'HR', 'LR RR', 'MACK3', 'SOEC', 'WOOK', 'MAE', 'BSUBN', 'BSCO',
       'SOBOU', 'DCHRY', 'LENMO', 'LATON', 'MITSL', 'GR21', 'BUIL',
       'HILDA', 'PORT', 'U8', 'R. RO', 'WHSP', 'INTEK', 'ININ', 'FRUGT',
       'KEN T', 'TOROT', 'FLI', 'PLYMU', 'PATI', 'CAR 2', 'SEV', 'CHINO',
       'VESA', 'PIESU', 'VAH H', 'WK VA', 'KINWO', 'MACO', 'FEREI',
       'YACHI', '9', 'JIUA', 'UPA', 'WEICH', 'GRDA', 'V OLK', 'MAGEN',
       'PORSI', 'BERIU', 'WO/FU', 'DACI', 'APRLL', 'IP', 'MERWR', 'PREZM',
       'IUB', 'FARBE', 'KEYST', 'BALA', 'BERCD', 'MARCY', 'INR', 'WORKL',
       'DUCK', 'HINOQ', 'KENRU', 'BURU', 'MASTU', 'HYNT', 'SIB', 'ONFUN',
       'MACON', 'R HOU', '18', 'BENTC', 'DIDRO', 'KEWAS', 'GHRY', 'FGT L',
       'MACTR', 'KFA', 'FLEEY', 'MERCC', 'ISHI', 'ALS', 'YAKAH', '5IIIS',
       'CYRS', 'CHTRY', 'ESTST', 'CHREG', 'MICKL', 'MASSE', 'STANC',
       'WOHS', 'NTRHH', 'NAVA', 'MR', 'PARIA', 'COYRI', 'CINAL', 'KW999',
       'HANJI', 'FAY', 'JRG', 'TESIG', 'ISV', 'IN/LI', 'HYA', 'SEAB',
       'PCRC', 'POIC', 'LUKSI', 'TONGH', 'FG', 'UNLO', 'WK/LI', 'CARGD',
       'MERMB', 'COUIL', 'WO/ID', 'TESHA', 'REMOV', 'CGERT', 'DUO',
       'FUMO', 'HARDL', 'MAW', 'ER', 'INJH', 'SWT', 'RI', 'FISO', '2004',
       'WRKHT', 'MERAN', 'MANAL', 'SIER', 'ARCUN', 'PAGGI', '2015',
       'SUNAR', 'MITSB', 'FRK', 'CHIS', 'BESTE', 'MEDA', 'FREIO', 'VWOIH',
       'NYUN', 'MECY', 'YALG', 'SART', 'SUCAT', '7WI', 'THONE', 'STAL',
       'DESPA', 'E-CHA', 'ASTO', 'JIS', 'CAOLD', 'ONT', 'KY TR', 'LA RD',
       'GENIV', 'ZHANG', 'WESPA', 'MERSE', 'GDAB', 'MULCH', 'FRHNR',
       'PORLE', 'NACJ', 'MHSUB', 'ISN', 'CORV', 'GUMMA', 'LOAD', 'PERT',
       'MECRE', 'KIPRO', 'VOLCA', 'LEISU', 'POAIC', 'WK HS', 'LF/RO',
       'JO', 'DHILL', 'STRAR', 'OMINI', 'ACURG', 'STUNG', 'RAMU', 'THEU',
       'TLXZ', 'WO/HD', 'GILIT', 'EVEIR', 'WO/OH', 'MASRC', 'UDREF',
       'LAMO', 'WDSW', 'UTLEY', 'LXS', 'CIDA', 'IBFR', 'AEUE', 'KEU',
       'PLTMO', 'PROHE', 'JEBWI', 'CASDI', 'SNZAK', 'MASEE', 'GRUMN',
       '8CADI', 'FRIGU', 'ME/BG', 'UTTLM', 'FEG', 'MAXAN', 'VE', 'POWL',
       'LA//R', 'IFINT', 'PACE', 'YESLA', 'IQSIK', 'PROAV', 'FERR3',
       'JOECI', 'UTUIT', 'TIFAN', 'KWUG', 'BENIT', 'NEAP', 'WS', 'VANNH',
       'JUNDA', 'WOLKW', 'SUARZ', 'IONFI', 'ZENH', 'UNDIO', 'G DAR',
       'RENWD', 'FREID', 'UTILH', 'IZUKI', 'TRIUI', 'HORAH', 'SHBAR',
       'CEWIL', 'FRELE', 'ELITE', 'JUR', 'MAXM', 'TI/M', 'THI/U', 'ITKCB',
       'CALIB', 'VNB', 'NATUS', 'NQR', 'HEN', 'CHETH', 'WRHSE', 'VATZ',
       'LDRV', 'VOLAN', 'LINHA', 'AVO', 'FE145', 'CAR20', 'SACHS',
       'CARFO', 'SPECI', 'HM2', 'COB C', 'GENWO', 'FRQC', 'POITI',
       '65283', 'GMCS', 'BERG', 'GRUHM', 'RANGG', 'MAGIC', 'FT LN',
       'SHERW', 'POPIA', 'SVZV', 'GR', 'GREST', 'POTE', '5ATU', 'USO',
       'COUNE', 'LARDR', 'RN/RO', 'FRVN', 'KIDRA', 'BURGM', 'POADS',
       'LRNNS', 'FRUCH', 'GR/D', 'SHENK', 'DATEN', 'ACURT', 'FEGH', 'INI',
       'CANTT', 'REYCO', 'VT/WG', 'MECH', 'INT F', 'BRENT', 'MIF', 'HEIS',
       'IINTE', 'VEROU', 'BURK', 'KR', 'SATAR', 'UTEL', 'MAZK', 'WEIST',
       'PLAZ', 'RELIF', 'UTIUT', 'BLB', 'MACJ', 'CARTS', 'HULSA', 'SENJO',
       'M GUZ', 'TOYAT', 'IRVIN', 'HOLDI', '04', 'SATWN', 'BAZD', 'PEDER',
       'DBLU', 'EIL', 'THRUX', 'AL DE', 'INTLV', 'TAO', 'HORAC', 'ONJMS',
       'HNYDI', 'DGUAN', 'APPOI', 'INFM', 'MEYG', 'LEXZ', 'ELDN', '34417',
       'FV', 'WRHR', 'SPRON', 'GNESI', 'ML/FU', 'FAUK', 'PPG', 'DOCA',
       'APRIU', 'FRED', 'CHRT', 'GRET', 'THOMP', 'KAIKA', 'CHRU', 'YA',
       'GRISS', 'ONIR', 'GE/SC', 'MECUY', 'SUBMA', 'CAADI', 'IUSUK',
       'HINQ', 'VIKS', 'MISS', 'HDY', 'CGHRY', 'LA/CO', 'MINZ', 'KIPEM',
       'PTB', 'JOG', 'WOEKH', 'CADIM', 'HENAL', 'VPLKS', 'VOLG', 'BEIGE',
       'SEABR', 'UTULI', 'REF', 'UNIBI', 'KNNW', 'POASC', 'VA/PO', 'DTK',
       'CDILL', 'TUER', 'ARO', 'TIENW', 'MI/FN', 'SUMME', 'WORT', 'SASUK',
       'PENWO', 'WEBST', '1115', 'UTR', 'KENDE', 'GLAVA', 'HALE', 'HUSQV',
       'VSTAR', 'STREE', '1U12R', 'WHEFI', 'SCTRO', 'GN', 'VANHI', 'TEMA',
       'BEAVT', 'ETRA', 'IMPEZ', 'JBAR', 'VKWGN', 'HAZDA', 'XAS', 'UTKIH',
       'FER/L', 'TOWNC', 'CUM', 'MACK/', 'MAZSE', 'SONIC', 'KNWO', 'AJDK',
       'CHOY', 'KELTZ', 'ILLIN', 'ACUTR', 'AAAIR', 'HANDY', 'CHRYU',
       '2WG', 'AURBE', 'IRT', 'YAMAY', 'V/OLK', 'INFIX', 'RADRA', 'SPRW',
       'ATC', 'PAIG', 'STERN', 'OLKS', 'MI/BE', 'E-Z L', 'SIGHT', 'INCD',
       'PRENO', 'R ROR', 'GLOR', 'UTILN', 'LODUS', 'HMDE', 'ME/BK', 'M2E',
       'HIFU', 'PIUDI', 'CENT', 'POST', 'RAMBA', ',LEXU', 'RAMP', 'HIACH',
       'MCTS', 'SERTD', 'FUDO', 'STERK', 'ACAUR', 'VWH', 'VOLUS', 'C',
       'FVA', 'FVM', 'L3I', 'KNAIL', 'RAMGE', 'TORRO', 'TOMS', 'MASET',
       'ND', 'HOMZ', 'UNIRE', 'FRIR', '6', 'WDI', 'CHLYS', 'SOLAC',
       'CHSY', 'MCL', 'ME FD', 'VR', 'GRETD', 'KAWOR', 'HRNO', 'FR. L',
       'CONNO', 'WERRI', 'IBFIN', 'LABO', 'BINO', '4ND', 'YINO', 'FRIH',
       'MEBE','ME/BE', 'MITSU', 'FRUEH',
       'INTER', 'FIAT', 'WORKH', 'LEXUS', 'VOLKS', 'CADIL', 'ACURA',
       'GMC', 'DODGE', 'INFIN', 'SUBAR', 'AUDI', 'ISUZU', 'MAZDA', 'HINO',
       'PETER', 'HYUND', 'PONTI', 'HIN', 'JEEP', 'MACK', 'BUICK',
       'ROVER', 'KIA', 'BMW', 'SMART', 'KENWO', 'NS/OT', 'VOLVO', 'CHRYS',
       'MERCU', 'PORSC', 'LINCO', 'MCI', 'RA/RO', 'GILL', 'SPRI', 'VANHO',
       'SATUR', 'STERL', 'GEO', 'SCION', 'UTILI', 'VESPA', 'SUZUK',
       'MASSA', 'CHECK', 'TESLA', 'TRAIL', 'JENSE', 'JAGUA', 'MASE', 'UD',
       'SAAB', 'MINI', 'NAVIS', 'MER', 'BERTO', 'OLDSM', 'PLYMO', 'TRIUM',
       'UTIL', 'YAMAH', 'DIAMO', 'FONTA', 'HAMME', 'FRIGH', 'FRIE',
       'WORK', 'HIND', 'DORSE', 'FEDEX', 'GRUMM', 'UNIFL', 'KENTU',
       'HUMME', 'UNIV', 'KW', 'MI/F', 'BENTL', 'VM', 'WORK/', 'DUCAT',
       'HARLE', 'SOLEC', 'HUYN', 'HYUN', 'FREG', 'HUMBE', 'WO/C', 'FTL',
       'VA/H', 'SMITH', 'UPS', 'WO/HO', 'KAWAS', 'ANCIA', 'FRGHT',
       'FERRA', 'FRGTL', 'SPARC', 'CARGO', 'PREVO', 'DATSU', 'FRE', 'STL',
       'EASTO', 'FR-L', 'FR/LI', 'FRD', 'PEUGE', '1', 'FC', 'PEDIC',
       'AL/R', 'H', 'UTI', 'FRTL', 'WORH', 'SIMCA', 'FRT L', 'WRK H',
       'INIFI', 'FR/LN', 'ROLLS', 'HR/DA', 'EAST', 'FRAT', 'WO/CH',
       'SEABO', 'COLLI', 'MAD', 'FRIG', 'AUSTI', 'AM/G', 'REITN', 'COAC',
       'ISUUZ', 'RENAU', 'FRG', 'HINOQ', 'POAIC', 'AMC', 'FRH', 'KEWO',
       'GIDNY', 'VAN', 'SCAN', 'AUE', 'CHOY', 'VOKLK', 'OKL', 'SETRA',
       'WABAS', 'GREAT', 'AMTR', 'LOTUS', 'STAR', 'GDAB', 'VAN H',
       'TESMA', 'THOMA', 'IC', 'JAUAR', 'KIDRA', 'HIRO', 'FRT /', 'FRGT',
       'INIFN', 'SPINT', 'BLUEB', 'WEST', 'FRLI', 'KENW', 'FUSO', 'KENIL',
       'WO/HS', 'LA RO', 'CHYST', 'BL/B', 'SIXTU', 'SUNBE', 'GREMT',
       'GRIF', 'CIMC', 'UDZ', 'STRIC', 'UT/M', 'VOLK,', 'HYRD', 'KI/M',
       'HART', 'FRLN', 'HIGHW', 'GENES', 'MONON', 'STOUG', 'SWVO', 'AJAX',
       'AS/M', 'MVT', 'TRITO', 'DT466', 'APP', 'FT/L', 'WORTY', 'WAB',
       'THM', 'GIL', 'NV', 'STUDE', 'LAROV', 'MARCU', 'BL/BI', 'VAN T',
       'KIDRO', 'WOLK', 'TRAC', 'GSB', 'SYBAR', 'APRIL', 'MERY', 'WO/H',
       'LAM', 'INTR', 'TRL', 'RAM.', 'SCLOA', 'LAYTO', 'MI', 'MOTO',
       'TESL', 'WHITE', 'WHORS', 'GD', 'COMM', 'LEXIU', 'WCC', 'UNHL',
       'DELOR', 'CADEL', 'ICBUS', 'GNC', 'HOMET', 'INTEL', 'CHER', 'FHTL',
       'MG', 'PETRB', 'WABA', 'LA/RE', 'HIWH', 'FRT', 'ALDE', 'HINI',
       'HAUN', 'MI FU', 'UTMA', 'POT', 'HUNN', '.INFI', 'TRUCK', 'VPG',
       'FR/L', 'HYNG', 'SOKL', 'BLUE', 'LAMBO', 'WKHS', 'MICKE', 'EZL',
       'FREIE', 'APPOX', 'THEUR', 'CRAE', 'FLINE', 'BCL', 'FISKE',
       'AMTRA', 'LENWO', 'PREV', 'MCIN', 'WRK', 'R ROV', 'FRER', 'VN',
       'WHILE', 'FEIG', 'LADA', 'DIAHA', 'FRGI', 'IC CE', 'DAEWO',
       'FOUNT', 'INETR', 'L/R', 'PGO', 'MINIC', 'CHSY', 'F/L', 'ROAD',
       'GOLD', 'ALFAR', 'WORKV', 'NISSR', 'TAV', 'OLDMO', 'WKH.', 'POITI',
       'FN/LT', 'HACK', 'GREIG', 'KENIW', 'GRE D', 'BRI', 'FREI', 'YUKO',
       'MASTE', 'MCRY', 'TRLR', 'THO', 'GLAVA', 'INTIL', 'MASTU', 'MAGIR',
       'RAN', 'FRGH', 'HIA', 'FL', 'SCIOR', 'COLL', 'OSHIK', 'VOLKA',
       'MOTOR', 'WINN', 'MOUIT', 'MCY', 'KIN', 'MORGA', 'LA-RO', 'FR/LA',
       'FR LI', 'TESCA', 'INTZ', 'DDERA', 'MITS', 'SUNAR', 'ITNE', 'VSIA',
       'IFIN', 'DENNI', 'MICK', 'WCSTR', 'THUNG', 'VOVL', 'CHASI', 'VANH',
       'FLAIR', 'PTRB', 'BENTC', 'MONO', 'BERIN', 'PIAGI', 'PIAJ', 'GV',
       'CDAIL', 'WHOR', 'ULTR', 'AUTOC', 'BRIDG', 'BURCK', 'MERC',
       'MAYBA', 'ZHANG', 'RHINO', 'RYDER', 'JAGUG', 'FONA', 'PICK',
       'FRIEG', 'ENTTE', 'HRY', 'GRUEH', 'SPECT', 'CHEB', 'FR L', 'FR LN',
       'MCI6', 'FLEAT', 'FR', 'PETE', 'ELKD', 'IIES', 'MHSU', 'HURI',
       'BSA', 'UT MA', 'LANDO', 'TRA', 'PINES', 'CVEV', 'SPORT', 'SOLE',
       'CAT', 'MIFI', 'LAN R', 'ANKAR', 'WHI F', 'FO/R', 'ATLAN', 'CA ON',
       'UT/MA', 'BV500', 'CODA', 'VA/HO', 'ALEXA', 'MERMB', 'ITNL',
       'UTI L', 'NISSO', 'SH LA', 'W HOR', 'BERSO', 'KENI', 'AERO',
       'WK HS', 'HYUAN', 'LARND', 'SMARY', 'MANAC', 'WOLVO', 'CORBE',
       'AREMO', 'UTLIN', 'FRHT', 'COURI', 'VANHH', 'KAUFM', '14064',
       'HMND', 'NEWF', 'MICKL', 'POACH', 'FRENA', 'ELDO', '7C', 'HMO',
       'ACUDA', 'STARC', 'VIRO', 'CHESY', 'CADA', 'WFL', 'FART', 'LANR',
       'FRANK', 'SPRIA', 'FL/LR', 'VHOOL', 'ST/C', 'WORKI', 'WH', 'ULITI',
       'WORKS', 'PB', 'EORKH', 'RAY', 'FN', 'TRIV', 'WRKHS', 'ZENTI',
       'ABART', 'MVON', 'HYUYN', 'SOUT', 'RO/R', 'J=HIN', 'SEMA', 'IU',
       'FR/LT', 'FREHT', 'PIAGG', 'MOBIL', 'GE/M', 'LAND/', 'PENSK',
       'DCLI', 'CAADI', 'GEM', 'SUARZ', 'KENHU', 'LNO/R', '.CHRY',
       'SATON', 'UTULI', 'STE', 'MAZER', 'HYUBD', 'DILLY', 'LX', 'HUGHE',
       'KQ', 'LA RA', 'WE/S', 'RA/R', 'FREGH', 'HYU N', 'HERC', 'BUT',
       'KAUF', 'STAIC', 'FROD', 'YMSID', 'EXVS', 'SADUR', 'AM/C', 'JONWA',
       'HUYAN', 'FIER', 'ANKA', 'BUDCO', 'PONSC', 'REFGO', 'FISO', 'GRD',
       'MG/BG', 'OINRB', 'CUB', 'KENWD', 'WOLLT', 'FRVAN', 'LA', 'TRACT',
       'SB', 'SEV', 'GDAVE', 'VOLZA', 'AWDRD', 'UITIL', 'WORKE', 'GREI',
       'WORTH', 'COB C', 'WORKN', 'HERCU', 'CANAM', 'REFG', 'FGT L',
       'UTILM', 'TLR', 'HERCE', 'VNHL', 'FRL', 'PANT', 'SKODA', 'KYMCO',
       'SOLBC', 'ODAI', 'FUZO', 'RA/LA', 'FHR', 'MICKY', 'BURG', 'UTIMA',
       'ISUZ', 'KENSW', 'WRKVA', 'VOLKO', 'LEIS', 'ORION', 'UYILI',
       'INFI', 'POTIA', 'HYLAN', 'PONTA', 'TR/T', 'CHLYS', 'DSUZU',
       'DJFIN', 'SEABR', 'MAXX', 'FL/LI', 'ACRUT', 'REF', 'KEWNO',
       'HARDL', 'MILLS', 'FIBER', 'FGT', 'PET', 'SATUM', 'FG', 'RHING',
       'RANE', 'NORRO', 'WV', 'PAGGI', 'KRYS', 'FREIR', 'FRVN', 'INERN',
       'HYNDY', 'HARTG', 'UNCB', 'NILED', 'GRE', 'ST/AL', 'MAROU',
       'AMERT', 'SIENA', 'LEUXS', 'YOI', 'MAXON', 'CHALS', 'AGGRC',
       'IN/LI', 'ASIMA', 'FT/LI', 'PORSG', 'CRIS', 'TEMS', 'KEW', 'G DAN',
       'BUGAT', 'UPSTR', 'NEVOS', 'GREG', 'RI', 'WARKH', 'WO KS', 'AEROM',
       'UPG', 'JINO', 'SEMI', 'FGHT', 'CITRO', 'AER', 'ME/BK', 'KIA3',
       'A', 'COVIE', 'SUBA', 'FAIL', 'VLS', 'JINDO', 'ENFIE', 'RAUSE',
       'NS/VO', 'KYMC', 'RANT', 'WORKL', 'PORSO', 'CORB', 'GEO/P',
       'KENOW', 'SOLEA', 'FTWD', 'WE/ST', 'SATRU', 'CARGS', 'HYUMD',
       'SHENZ', 'BUICH', 'BIKE', 'EIA', 'MCA', 'BART', 'OPELP', 'ST/A',
       'MAB', 'FRGL', 'WRKHO', 'XLSP', 'UNKNO', 'WK', 'AM/T', 'HINIO',
       'SAN', 'ILLIN', 'TOMOS', 'FUSP', 'BUS', 'BV 35', 'CONNE', 'PROVO',
       'PIUGG', 'CARG', 'RAGER', 'CADIH', 'IRP', 'USPS', 'SALEE', 'MI/FL',
       'PUOC', 'ACL', 'VSP', 'FR HT', 'BA', 'CHTH', 'UAB', 'VOLER',
       'HYLIN', 'NEAP', 'K.W.', 'STANC', 'VOLWO', 'RNG R', 'PROVS',
       'DELIV', 'TRALE', 'ME/B', 'ROKET', 'DA1', 'MIST', 'WKH', 'WANC',
       'TELSA', 'ALERO', 'FRELC', 'INTIN', 'GTR/H', 'KENS', 'MOTER',
       'LADRO', 'AVURA', 'FRE L', 'PTRBL', 'HENO', 'FREZG', 'ZENIT',
       'DELV', 'HAULE', 'YA', 'DIVEL', 'ARMOR', 'MORC', 'SAMEN', 'MEREU',
       'NWCLM', 'BESPA', 'CHRU', 'UNIVE', 'VNB', 'POIN', 'RCB', 'LODC',
       'UWGOL', 'CAYTO', 'WINNE', 'HYDI', 'KAUFF', 'RINO', 'MESSE',
       'AUSTO', 'YW', 'MAS', 'FORTU', 'AZERA', 'GREDN', 'KEWWT', 'DUKAD',
       'BOX', 'MOTOG', 'CA/EX', 'ST OU', 'SCIRA', 'TMAX', 'PTR-B', 'OMR',
       'EDGE', 'COZY', 'LDV', 'CH', 'DEL', 'KNWO', 'FREY', 'RED', 'LAREO',
       'COLEM', 'TRI S', 'INFTL', 'GYON', 'SPART', 'G/D', 'BERI', 'PSD',
       'DEMA', 'QUICK', 'GENUI', 'UHAUL', 'UTIAL', 'PREVE', 'FOD',
       'HECHT', 'FRIL', 'FREL', 'SPIN', 'WORW', 'WT', 'ETERB', 'KWAS',
       'AWCA', 'UMC', 'FEDE', 'PHEO', 'TRUC', 'STRL', 'ZHING', 'WINNI',
       'N/S', 'BRUIC', 'WRKHA', 'INNFI', 'CHYRI', 'INFIY', 'UTL', 'PONI',
       'CHY', 'KH', 'TR/TL', 'HNO', 'REBEN', 'DENNY', 'TRIPL', 'WAEAS',
       'LH/KO', 'CUST', 'AUCO', 'INTI', 'CHEET', 'WK/H', 'HARDW', 'K/W',
       'MARAR', 'FORLE', 'FHRT', 'HA/DO', 'WRK/H', 'PORT', 'APPX',
       'CADIZ', 'LE', 'PETR', 'FRIEI', 'SONOT', 'GRTDA', 'HDVO', 'URENT',
       'MLT', 'W/H', 'APPT', 'NF', '2004', 'SUZU', 'PCRC', 'K', 'HULSA',
       'FRELI', 'MG/BE', 'LAIRO', 'VV', 'LO/R', 'TW', 'USP', 'L R',
       'RAN R', 'SUI', 'VOTVO', 'MO/V', 'PTR', 'ZKMT', 'LND R', 'HIINO',
       'USYZY', 'STELL', 'PIGGI', 'BOXFE', 'INEI', 'KENMO', 'PEYMO', 'ET',
       'WROKH', 'FR/NE', '67592', 'E', 'INT V', 'W/HO', 'GRAET', 'CRYST',
       'MAZ', 'FK', 'REIG', 'MISU', 'SMARK', 'CHADE', 'ME /', 'ACADE',
       'WORKM', 'PONTY', 'STAL', 'CHAPP', 'SERR', 'UTRY', 'PANER', 'INN',
       'KUSH', 'CHSTL', 'FEDGI', 'HIUNT', 'ATC I', 'DEAN', 'FREID',
       'NORTH', 'MIFY', 'REM', 'JONW', 'HYDU', 'TRIUI', 'THOR', 'ADD',
       'DURAS', '67600', 'MASSE', 'LEXAS', 'FRG V', 'WO HS', 'CUBCA',
       'UHK', 'GREA', 'GRDN', 'HNDAI', 'VOLTS', 'UES', 'SCARA', 'TROG',
       'INFNI', 'MARCH', 'ITILI', 'MASEE', 'CHTRY', 'SUYBA', 'PRU',
       'V OLV', 'CIBA', 'GO 4', 'ISHI', 'YAMAC', 'KENC', 'GE/C', 'FLIDE',
       'HIACH', 'GENZE', 'ISUGU', 'GDT', 'VLKWG', 'LUFKI', 'CYSLE',
       'MIFUS', 'GOV', 'YD', 'BL 30', 'SUBMA', 'JEGLA', 'BOULE', 'LOADR',
       'WHCC', 'TRAN', 'ME FD', 'TRATI', 'SADAN', 'HAR D', 'ONT', 'SOLIC',
       'LI', 'FOUR', 'IA', 'TAL', 'SMRT', 'PLMYO', 'UNIBI', 'DUTCH',
       'LDRV', 'INIF', 'WRKG', 'CEWIL', 'ASTO', 'FREIC', 'VANI', 'HYBRI',
       'KID R', 'KENLW'],'OTHER')

# %%
df['Vehicle Make'].unique()
# Out:
# array(['HONDA', 'OTHER', 'NISSA', 'FORD', 'TOYOT'], dtype=object)

# %%
df.groupby(['Vehicle Make'])['Vehicle Make'].count().sort_values(ascending=False)
# Out:
# Vehicle Make
# OTHER    476270
# FORD      99902
# TOYOT     83918
# HONDA     76576
# NISSA     63334
# Name: Vehicle Make, dtype: int64

# %%
df['Vehicle Year'].unique()
# Out:
# array(['<2000', '>2000'], dtype=object)

# %%
c
# Out:
# Vehicle Year
# <2000    765812
# >2000     34188
# Name: Vehicle Year, dtype: int64

# %%
df['Vehicle Year'] = df['Vehicle Year'].replace([2009, 2001, 2006, 2004, 2015, 2008, 2014, 2005, 2010, 2011,
          0, 2016, 2013, 2002, 2007, 2012, 2003,2017, 1988,
       2065,
       2018, 2025, 2068, 2067,2052,
        2066, 1976, 2019,
       2058, 2026, 2063, 2062, 2061, 2020, 2059, 2051, 2069, 2053,
       2054, 2049, 2064,2055,2057,2022,2050,2039,2027,2040, 2028, 2035, 2045, 2021, 2024, 2023, 2060, 2041,
       2037, 2042, 2046, 2047, 2043],'<2000')

# %%
df['Vehicle Year'] = df['Vehicle Year'].replace([1997, 1996, 1995, 1998, 1980, 1999, 1989, 1992, 1994,
       1993, 1991, 1987, 1990, 1986, 1985, 1972, 1984, 1982, 1983, 1979,
       1974, 1977, 1981, 1970, 1975, 1978, 1971, 1973],'>2000')

# %%
df.groupby(['Violation County'])['Violation County'].count().sort_values(ascending=False)
# Out:
# Violation County
# NY     314604
# K      204169
# QNS    170023
# BX     100035
# R       11169
# Name: Violation County, dtype: int64

# %%
bodytype_key = {"SUBN":"SUV",
                "4DSD":"CAR", "SDN":"CAR","2DSD":"CAR", "4S":"CAR", "SEDN":"CAR",
                "VAN":"OTHER","DELV":"OTHER","TAXI":"OTHER","UTIL":"OTHER",
                "PICK":"TRUCK", "TRAC":"TRUCK", "P-U":"TRUCK","TK":"TRUCK","UT":"TRUCK","PKUP":"TRUCK",
                "4 DR":"OTHER", "REFG":"OTHER","4D":"OTHER","4W":"OTHER", "FLAT":"OTHER","TR/C":"OTHER", "T/CR":"OTHER", "FOUR":"OTHER",
                "CONV":"CAR",
                "WAGO":"CAR",
                "BUS":"OTHER",
                "TRLR":"OTHER",
                "MCY":"OTHER",
                "TOW":"OTHER"
                 }

# %%
 df["Vehicle Body Type"].replace(bodytype_key, inplace=True)

# %%
bodytype_key2 = {"SUV":"SUV",
                "CAR":"CAR",
                "OTHER":"OTHER","DUMP":"OTHER", "SEMI":"OTHER", 
                "TRUCK":"TRUCK","TR":"TRUCK"
                 }

# %%
 df["Vehicle Body Type"].replace(bodytype_key2, inplace=True)

# %%
types = list(dict(df['Vehicle Body Type'].value_counts()).keys())
othertypes = types[4:]
othertypes
# Out:
# ['TRAI',
#  'STAK',
#  'TRUC',
#  'BOAT',
#  'MOTO',
#  'SWT',
#  'TRL',
#  'I',
#  'TANK',
#  'TWOD',
#  'LIM',
#  'TT',
#  'BS',
#  'TRK',
#  'TRC',
#  'H/WH',
#  'TL',
#  'P/SH',
#  'TRT',
#  'S/SP',
#  'W/DR',
#  'MC',
#  'TR/E',
#  'FREI',
#  'MCC',
#  'TRAV',
#  'MOT',
#  'MOBL',
#  'SN/P',
#  'CUST',
#  'BOXT',
#  'TLR',
#  'R/RD',
#  'REFR',
#  'LTRL',
#  'EMVR',
#  'SCHO',
#  'CMIX',
#  'COUP',
#  'N',
#  'SCOO',
#  'FIAT',
#  'R',
#  'TOWT',
#  'REF',
#  'POLE',
#  'A',
#  'SMAR',
#  'JEEP',
#  'H/TR',
#  'RV',
#  'REFI',
#  'TCR',
#  'II',
#  'DELI',
#  'HRSE',
#  'IL',
#  'MINI',
#  'HWH',
#  'UHAU',
#  'VANT',
#  'LIMO',
#  'WGN',
#  'RPLC',
#  'OMR',
#  'RD/S',
#  'SUBA',
#  'H/IN',
#  'TRA',
#  'CB',
#  'INTE',
#  'MOPE',
#  'TKR',
#  'COUR',
#  'BROW',
#  'TRAL',
#  'WORK',
#  'SRF',
#  'WHIT',
#  'TRKT',
#  'E',
#  'NS',
#  'S',
#  'YDSD',
#  'MS',
#  'LCOM',
#  'RF',
#  'UTL',
#  'APP',
#  'FONT',
#  'MCI',
#  'UD',
#  'T',
#  'TOWN',
#  'IN',
#  'D',
#  'YD',
# ...

# %%
df['Vehicle Body Type'].replace(othertypes, "OTHER", inplace=True)

# %%
df['Vehicle Body Type'].unique()
# Out:
# array(['CAR', 'SUV', 'TRUCK', 'OTHER'], dtype=object)

# %%
df.to_csv('c1.csv')
